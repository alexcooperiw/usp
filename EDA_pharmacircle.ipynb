# %% [markdown]
# ### TODO
#
# get unii code from gsrs ref
# get duns numbers
# need understand company and fdf better-- are they the same?

# %%
import os
print(os.environ)
# Out:
# environ({'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': '73e874bf5a39', 'JUPYTERHUB_API_TOKEN': 'eae6ab5a500549f0bfb703a6537f57a9', 'JPY_API_TOKEN': 'eae6ab5a500549f0bfb703a6537f57a9', 'JUPYTERHUB_CLIENT_ID': 'jupyterhub-user-zhengrongma', 'JUPYTERHUB_HOST': '', 'JUPYTERHUB_OAUTH_CALLBACK_URL': '/user/zhengrongma/oauth_callback', 'JUPYTERHUB_USER': 'zhengrongma', 'JUPYTERHUB_SERVER_NAME': '', 'JUPYTERHUB_API_URL': 'http://d6f381c37041:8081/hub/api', 'JUPYTERHUB_ACTIVITY_URL': 'http://d6f381c37041:8081/hub/api/users/zhengrongma/activity', 'JUPYTERHUB_BASE_URL': '/', 'JUPYTERHUB_SERVICE_PREFIX': '/user/zhengrongma/', 'MEM_LIMIT': '21474836480', 'MEM_GUARANTEE': '5368709120', 'CPU_LIMIT': '6.0', 'CPU_GUARANTEE': '1.0', 'USER': 'zhengrongma', 'NB_USER': 'zhengrongma', 'USER_ID': '1010', 'NB_UID': '1010', 'HOME': '/home/zhengrongma', 'LC_ALL': 'C.UTF-8', 'LANG': 'C.UTF-8', 'ANSIBLE_ROLES_PATH': '/ansible/roles', 'KERNEL_LAUNCH_TIMEOUT': '40', 'JPY_PARENT_PID': '1', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})

# %%
#get list of pharmacircle files
from os import listdir
from os.path import isfile, join
path =  "/home/zhengrongma/supply_chain_project/data/pharmacircle/"
files = [f for f in listdir(path) if isfile(join(path, f))]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('abc').getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)

#rdd = sc.textFile("file:///supply_chain_project/data/pharmacircle/api_manufacturer.csv")
#api_manufacturer = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/api_manufacturer.csv")

# %%
#get number of rows in each table
def get_row_ct(path):
    row_ct = []
    for f in files:
        to_open = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv(path + f)
        row_ct.append((f, to_open.count()))
    return row_ct   
        
row_ct = get_row_ct("/home/zhengrongma/supply_chain_project/data/pharmacircle/")

# %%
row_ct
# Out:
# [('pc_form.csv', 224),
#  ('pc_territory.csv', 279),
#  ('api_manufacturer.csv', 110387),
#  ('Sales_Company.csv', 54682),
#  ('pc_molecule.csv', 3984),
#  ('Sales.csv', 15971),
#  ('pc_dosing_strength_compound.csv', 145463),
#  ('pc_branch.csv', 1841),
#  ('pc_dosing_strength_ingredient.csv', 399027),
#  ('fdf_manufacturer.csv', 77561),
#  ('Sales_Compound.csv', 26350),
#  ('Branch_Hierarchy.csv', 1825),
#  ('pc_dosing_strength.csv', 53826),
#  ('pc_compound.csv', 107064),
#  ('pc_compound_combined.csv', 43901),
#  ('Sales_Territory.csv', 54402),
#  ('pc_excipient.csv', 3385),
#  ('pc_company.csv', 3547)]

# %%
import pyspark.sql.functions as F
for f in files:
    to_open = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv(path + f)
    print(f)
    print(to_open.agg(*(100.0*(F.count(F.col(c))/to_open.count()).alias(c) for c in to_open.columns)))
# Out:
# pc_form.csv
# +---------------------------------------------+-------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------+
# |((count(form_id) / 224) AS `form_id` * 100.0)|((count(form_name) / 224) AS `form_name` * 100.0)|((count(parent_form_id) / 224) AS `parent_form_id` * 100.0)|((count(parent_route) / 224) AS `parent_route` * 100.0)|
# +---------------------------------------------+-------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------+
# |                                        100.0|                                            100.0|                                                        0.0|                                                  100.0|
# +---------------------------------------------+-------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------+
#
# pc_territory.csv
# +-------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+
# |((count(territory_id) / 279) AS `territory_id` * 100.0)|((count(territory_name) / 279) AS `territory_name` * 100.0)|((count(parent_id) / 279) AS `parent_id` * 100.0)|((count(special_type) / 279) AS `special_type` * 100.0)|((count(abbreviation) / 279) AS `abbreviation` * 100.0)|
# +-------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+
# |                                                  100.0|                                                      100.0|                                75.62724014336918|                                     2.5089605734767026|                                      63.08243727598566|
# +-------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+
#
# api_manufacturer.csv
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+
# |((count(api_manufacturer) / 110387) AS `api_manufacturer` * 100.0)|((count(source) / 110387) AS `source` * 100.0)|((count(duns_number) / 110387) AS `duns_number` * 100.0)|((count(fei) / 110387) AS `fei` * 100.0)|((count(api_manufacturer_address) / 110387) AS `api_manufacturer_address` * 100.0)|((count(country) / 110387) AS `country` * 100.0)|((count(api) / 110387) AS `api` * 100.0)|((count(unii_code) / 110387) AS `unii_code` * 100.0)|((count(CAS_registry) / 110387) AS `CAS_registry` * 100.0)|
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+
# |                                                 99.97825830940238|                             99.97825830940238|                                      2.3481025845434695|                       2.176886771087175|                                                                 73.20517814597733|                               92.26811128121972|                       99.97191698297807|                                   2.332702220370152|                                        1.7656064572821075|
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+
#
# Sales_Company.csv
# +-------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------+---------------------------------------------------------+
# |((count(sales_id) / 54682) AS `sales_id` * 100.0)|((count(sales_company_id) / 54682) AS `sales_company_id` * 100.0)|((count(sales_territory_id) / 54682) AS `sales_territory_id` * 100.0)|((count(company_id) / 54682) AS `company_id` * 100.0)|((count(company_role) / 54682) AS `company_role` * 100.0)|
# +-------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------+---------------------------------------------------------+
# |                                            100.0|                                                            100.0|                                                                100.0|                                                100.0|                                       2.6334077027175304|
# +-------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------+---------------------------------------------------------+
#
# pc_molecule.csv
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+
# |((count(molecule_id) / 3984) AS `molecule_id` * 100.0)|((count(molecule_name) / 3984) AS `molecule_name` * 100.0)|((count(synonym) / 3984) AS `synonym` * 100.0)|((count(unii_number) / 3984) AS `unii_number` * 100.0)|((count(CAS_registry) / 3984) AS `CAS_registry` * 100.0)|
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+
# |                                                 100.0|                                                     100.0|                             81.70180722891565|                                     53.26305220883534|                                       90.06024096385542|
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+
#
# Sales.csv
# +-------------------------------------------------+-----------------------------------------+-------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------+
# |((count(sales_id) / 15971) AS `sales_id` * 100.0)|((count(year) / 15971) AS `year` * 100.0)|((count(descriptive) / 15971) AS `descriptive` * 100.0)|((count(references) / 15971) AS `references` * 100.0)|((count(reference_hyperlink) / 15971) AS `reference_hyperlink` * 100.0)|
# +-------------------------------------------------+-----------------------------------------+-------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------+
# |                                            100.0|                                    100.0|                                     20.624882599711977|                                    96.32458831632333|                                                      7.707720242940328|
# +-------------------------------------------------+-----------------------------------------+-------------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------------------------+
#
# pc_dosing_strength_compound.csv
# +----------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------------------------------------------------------+----------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
# |((count(dosing_strength_compound_id) / 145463) AS `dosing_strength_compound_id` * 100.0)|((count(dosing_id) / 145463) AS `dosing_id` * 100.0)|((count(dosing_strength_id) / 145463) AS `dosing_strength_id` * 100.0)|((count(dosing_strength_approval_id) / 145463) AS `dosing_strength_approval_id` * 100.0)|((count(dosing_strength_ingredient_group_id) / 145463) AS `dosing_strength_ingredient_group_id` * 100.0)|((count(compound_id) / 145463) AS `compound_id` * 100.0)|((count(family_id) / 145463) AS `family_id` * 100.0)|((count(mysql_user) / 145463) AS `mysql_user` * 100.0)|((count(moment_updated) / 145463) AS `moment_updated` * 100.0)|((count(moment_inserted) / 145463) AS `moment_inserted` * 100.0)|
# +----------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------------------------------------------------------+----------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
# |                                                                       99.99931253995862|                                   99.99931253995862|                                                      99.6033355561208|                                                                       4.954524518262375|                                                                                       94.46938396705691|                                       99.97525143851014|                                   99.99931253995862|                                      89.7059733402996|                                             99.99931253995862|                                               99.99931253995862|
# +----------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------------+----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------------------------------------------------------+----------------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
#
# pc_branch.csv
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+
# |((count(branch_id) / 1841) AS `branch_id` * 100.0)|((count(abbreviation) / 1841) AS `abbreviation` * 100.0)|((count(branch_name) / 1841) AS `branch_name` * 100.0)|((count(branch_synonym) / 1841) AS `branch_synonym` * 100.0)|((count(full_name) / 1841) AS `full_name` * 100.0)|((count(explanation) / 1841) AS `explanation` * 100.0)|((count(hyperlink) / 1841) AS `hyperlink` * 100.0)|((count(top_page) / 1841) AS `top_page` * 100.0)|((count(type) / 1841) AS `type` * 100.0)|((count(hide_in) / 1841) AS `hide_in` * 100.0)|((count(dds_type) / 1841) AS `dds_type` * 100.0)|
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+
# |                                             100.0|                                      11.298207495926126|                                     99.94568169473112|                                           36.93644758283541|                               0.27159152634437805|                                     4.942965779467681|                                21.944595328625745|                             0.16295491580662683|                       99.89136338946226|                            1.1950027159152634|                               98.91363389462249|
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+
#
# pc_dosing_strength_ingredient.csv
# +--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+----------------------------------------------------------------+----------------------------------------------+------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
# |((count(dosing_strength_ingredient_id) / 399027) AS `dosing_strength_ingredient_id` * 100.0)|((count(dosing_strength_ingredient_group_id) / 399027) AS `dosing_strength_ingredient_group_id` * 100.0)|((count(family_id) / 399027) AS `family_id` * 100.0)|((count(ingredient_type) / 399027) AS `ingredient_type` * 100.0)|((count(ingredient_id) / 399027) AS `ingredient_id` * 100.0)|((count(excipient_usage) / 399027) AS `excipient_usage` * 100.0)|((count(amount) / 399027) AS `amount` * 100.0)|((count(unit) / 399027) AS `unit` * 100.0)|((count(mysql_user) / 399027) AS `mysql_user` * 100.0)|((count(moment_updated) / 399027) AS `moment_updated` * 100.0)|((count(moment_inserted) / 399027) AS `moment_inserted` * 100.0)|
# +--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+----------------------------------------------------------------+----------------------------------------------+------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
# |                                                                                       100.0|                                                                                                   100.0|                                               100.0|                                                           100.0|                                                       100.0|                                               16.59010543146203|                            26.142090635470783|                        26.159633308021764|                                     88.85263403228353|                                                         100.0|                                                           100.0|
# +--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+----------------------------------------------------------------+----------------------------------------------+------------------------------------------+------------------------------------------------------+--------------------------------------------------------------+----------------------------------------------------------------+
#
# fdf_manufacturer.csv
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+
# |((count(fdf_manufacturer) / 77561) AS `fdf_manufacturer` * 100.0)|((count(source) / 77561) AS `source` * 100.0)|((count(duns_number) / 77561) AS `duns_number` * 100.0)|((count(fei) / 77561) AS `fei` * 100.0)|((count(fdf_manufacturer_address) / 77561) AS `fdf_manufacturer_address` * 100.0)|((count(country) / 77561) AS `country` * 100.0)|((count(product_name) / 77561) AS `product_name` * 100.0)|((count(NDC_code) / 77561) AS `NDC_code` * 100.0)|((count(fdf) / 77561) AS `fdf` * 100.0)|((count(applicant) / 77561) AS `applicant` * 100.0)|((count(marketing_category_name) / 77561) AS `marketing_category_name` * 100.0)|((count(dosage_form) / 77561) AS `dosage_form` * 100.0)|((count(route_of_administration) / 77561) AS `route_of_administration` * 100.0)|((count(excipient_name) / 77561) AS `excipient_name` * 100.0)|((count(excipient_synonym) / 77561) AS `excipient_synonym` * 100.0)|
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+
# |                                                            100.0|                                        100.0|                                     61.698534057064755|                      52.71334820334962|                                                               38.300176635164576|                              18.62662936269517|                                        99.99742138445869|                               61.698534057064755|                                  100.0|                                  61.69982336483542|                                                             61.698534057064755|                                      88.54965768878688|                                                              79.36720774616109|                                            78.66066708784054|                                                 0.7439305836696277|
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+
#
# Sales_Compound.csv
# +-------------------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+
# |((count(sales_compound_id) / 26350) AS `sales_compound_id` * 100.0)|((count(sales_id) / 26350) AS `sales_id` * 100.0)|((count(compound_id) / 26350) AS `compound_id` * 100.0)|
# +-------------------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+
# |                                                              100.0|                                            100.0|                                                  100.0|
# +-------------------------------------------------------------------+-------------------------------------------------+-------------------------------------------------------+
#
# Branch_Hierarchy.csv
# +--------------------------------------------------+------------------------------------------------+
# |((count(id_parent) / 1825) AS `id_parent` * 100.0)|((count(id_child) / 1825) AS `id_child` * 100.0)|
# +--------------------------------------------------+------------------------------------------------+
# |                                             100.0|                                           100.0|
# +--------------------------------------------------+------------------------------------------------+
#
# pc_dosing_strength.csv
# +---------------------------------------------------------------------+---------------------------------------------------+-----------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+
# |((count(dosing_strength_id) / 53826) AS `dosing_strength_id` * 100.0)|((count(family_id) / 53826) AS `family_id` * 100.0)|((count(form_id) / 53826) AS `form_id` * 100.0)|((count(mysql_user) / 53826) AS `mysql_user` * 100.0)|((count(moment_updated) / 53826) AS `moment_updated` * 100.0)|((count(moment_inserted) / 53826) AS `moment_inserted` * 100.0)|
# +---------------------------------------------------------------------+---------------------------------------------------+-----------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+
# |                                                                100.0|                                              100.0|                              99.92754430944153|                                    99.86809348641921|                                                        100.0|                                                          100.0|
# +---------------------------------------------------------------------+---------------------------------------------------+-----------------------------------------------+-----------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+
#
# pc_compound.csv
# +--------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+--------------------------------------------------- ...
# |((count(compound_id) / 107064) AS `compound_id` * 100.0)|((count(product_name) / 107064) AS `product_name` * 100.0)|((count(product_synonym) / 107064) AS `product_synonym` * 100.0)|((count(molecule_id_1) / 107064) AS `molecule_id_1` * 100.0)|((count(molecule_id_2) / 107064) AS `molecule_id_2` * 100.0)|((count(molecule_id_3) / 107064) AS `molecule_id_3` * 100.0)|((count(molecule_id_4) / 107064) AS `molecule_id_4` * 100.0)|((count(type) / 107064) AS `type` * 100.0)|((count(generic_or_innovator) / 107064) AS `generic_or_innovator` * 100.0)|((count(therapeutic_category_id) / 107064) AS `therapeutic_category_id` * 100.0)|((count(therapeutic_group_id) / 107064) AS `therapeutic_group_id` * 100.0)|((count(phase) / 107064) AS `phase` * 100.0)|((count(indication_explanation) / 107064) AS `indication_explanation` * 100.0)|((count(route_branch_id) / 107064) AS `route_branch_id` * 100.0)|((count(drug_delivery_branch_id_1) / 107064) AS `drug_delivery_branch_id_1` * 100.0)|((count(drug_delivery_branch_id_2) / 107064) AS `drug_delivery_branch_id_2` * 100.0)|((count(drug_delivery_branch_id_3) / 107064) AS `drug_delivery_branch_id_3` * 100.0)|((count(drug_delivery_branch_id_4) / 107064) AS `drug_delivery_branch_id_4` * 100.0)|((count(product_originator_company_id_1) / 107064) AS `product_originator_company_id_1` * 100.0)|((count(product_originator_company_id_2) / 107064) AS `product_originator_company_id_2` * 100.0)|((count(dds_technology_owner_company_id_1) / 107064) AS `dds_technology_owner_company_id_1` * 100.0)|((count(dds_technology_owner_company_id_2) / 107064) AS `dds_technology_owner_company_id_2` * 100.0)|((count(discovery_technology_owner_company_id) / 107064) AS `discovery_technology_owner_company_id` * 100.0)|((count(previous_partner_company_id_1) / 107064) AS `previous_partner_company_id_1` * 100.0)|((count(previous_partner_company_id_2) / 107064) AS `previous_partner_company_id_2` * 100.0)|((count(compound_company_id_1) / 107064) AS `compound_company_id_1` * 100.0)|((count(compound_company_id_2) / 107064) AS `compound_company_id_2` * 100.0)|((count(compound_company_id_3) / 107064) AS `compound_company_id_3` * 100.0)|((count(compound_company_id_4) / 107064) AS `compound_company_id_4` * 100.0)|((count(company_role_1) / 107064) AS `company_role_1` * 100.0)|((count(company_role_2) / 107064) AS `company_role_2` * 100.0)|((count(company_role_3) / 107064) AS `company_role_3` * 100.0)|((count(company_role_4) / 107064) AS `company_role_4` * 100.0)|((count(company_explanation) / 107064) AS `company_explanation` * 100.0)|((count(territory_id) / 107064) AS `territory_id` * 100.0)|((count(manufacturing_details) / 107064) AS `manufacturing_details` * 100.0)|((count(API_manufacturing_partner_company_id_1) / 107064) AS `API_manufacturing_partner_company_id_1` * 100.0)|((count(explanation_API_1) / 107064) AS `explanation_API_1` * 100.0)|((count(API_manufacturing_partner_company_id_2) / 107064) AS `API_manufacturing_partner_company_id_2` * 100.0)|((count(explanation_API_2) / 107064) AS `explanation_API_2` * 100.0)|((count(API_manufacturing_partner_company_id_3) / 107064) AS `API_manufacturing_partner_company_id_3` * 100.0)|((count(explanation_API_3) / 107064) AS `explanation_API_3` * 100.0)|((count(formulation_manufacturing_partner_company_id_1) / 107064) AS `formulation_manufacturing_partner_company_id_1` * 100.0)|((count(explanation_formulation_manufacturing_1) / 107064) AS `explanation_formulation_manufacturing_1` * 100.0)|((count(formulation_manufacturing_partner_company_id_2) / 107064) AS `formulation_manufacturing_partner_company_id_2` * 100.0)|((count(explanation_formulation_manufacturing_2) / 107064) AS `explanation_formulation_manufacturing_2` * 100.0)|((count(formulation_manufacturing_partner_company_id_3) / 107064) AS `formulation_manufacturing_partner_company_id_3` * 100.0)|((count(explanation_formulation_manufacturing_3) / 107064) AS `explanation_formulation_manufacturing_3` * 100.0)|((count(parent_compound_id) / 107064) AS `parent_co ...
# +--------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+--------------------------------------------------- ...
# |                                       99.99159381304639|                                         99.99159381304639|                                              21.045356048718524|                                           99.99159381304639|                                           12.28797728461481|                                          2.2836807890607487|                                          0.7145258910558171|                         99.99065979227379|                                                         98.47381005753569|                                                               99.99159381304639|                                                         44.49207950384817|                           99.99159381304639|                                                             44.16610625420309|                                                99.9364865874617|                                                                   99.93742060823433|                                                                   4.673839946200403|                                                                  1.1441754464619294|                                                                0.019614436225061645|                                                                               18.94287528954644|                                                                               4.493573937084361|                                                                                   9.432675782709406|                                                                                   4.291825450198012|                                                                                          1.3459239333482778|                                                                            5.19502353732347|                                                                          1.0059403721138758|                                                           99.99159381304639|                                                           35.02391093177912|                                                          10.868265710229394|                                                           2.641410744974968|                                             99.37514010311588|                                            10.926174998131959|                                            1.2291713367705297|                                           0.13543301203018757|                                                      2.4844952551744752|                                         96.69356646491818|                                                          3.7781140252559213|                                                                                             3.312971680490174|                                                  1.6364043936337145|                                                                                            0.5762908167077636|                                                  0.2036165284315923|                                                                                           0.12982888739445567|                                                 0.05323918403945303|                                                                                                             5.150190540237615|                                                                                              3.7220727788986023|                                                                                                            0.5277217365314205|                                                                                             0.25872375401628933|                                                                                                           0.06818351640140477|                                                                                             0.03362474781439139|                                                    ...
# +--------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------+--------------------------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------------------+----------------------------------------------------------+----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+--------------------------------------------------- ...
#
# pc_compound_combined.csv
# +---------------------------------------------------------+-------------------------------------------------+-------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------+---------------------------------------------+-----------------------------------------------------------------+-----------------------------------------------------------+
# |((count(product_name) / 43901) AS `product_name` * 100.0)|((count(molecule) / 43901) AS `molecule` * 100.0)|((count(route) / 43901) AS `route` * 100.0)|((count(owner_company) / 43901) AS `owner_company` * 100.0)|((count(partners) / 43901) AS `partners` * 100.0)|((count(dd_technology_owner) / 43901) AS `dd_technology_owner` * 100.0)|((count(manufacturers) / 43901) AS `manufacturers` * 100.0)|((count(product_originators) / 43901) AS `product_originators` * 100.0)|((count(ATC_code) / 43901) AS `ATC_code` * 100.0)|((count(excipient) / 43901) AS `excipient` * 100.0)|((count(primary_packaging) / 43901) AS `primary_packaging` * 100.0)|((count(drug_delivery_branch) / 43901) AS `drug_delivery_branch` * 100.0)|((count(generic_or_innovator) / 43901) AS `generic_or_innovator` * 100.0)|((count(world_sales) / 43901) AS `world_sales` * 100.0)|((count(smiles) / 43901) AS `smiles` * 100.0)|((count(water_solubility) / 43901) AS `water_solubility` * 100.0)|((count(melting_point) / 43901) AS `melting_point` * 100.0)|
# +---------------------------------------------------------+-------------------------------------------------+-------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------+---------------------------------------------+-----------------------------------------------------------------+-----------------------------------------------------------+
# |                                                    100.0|                                            100.0|                          99.89521878772693|                                                      100.0|                                42.92840709778821|                                                      5.188947859957632|                                         7.5169130543723375|                                                      11.12503132047106|                                78.58135349992027|                                  44.54568233069862|                                                  18.78317122616797|                                                        99.89749664016765|                                                        98.77223753445253|                                     2.4783034555021524|                                        100.0|                                                            100.0|                                                      100.0|
# +---------------------------------------------------------+-------------------------------------------------+-------------------------------------------+-----------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------------------+-----------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------+---------------------------------------------+-----------------------------------------------------------------+-----------------------------------------------------------+
#
# Sales_Territory.csv
# +---------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+---------------------------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------+
# |((count(sales_territory_id) / 54402) AS `sales_territory_id` * 100.0)|((count(sales_id) / 54402) AS `sales_id` * 100.0)|((count(territory_id) / 54402) AS `territory_id` * 100.0)|((count(other_territories) / 54402) AS `other_territories` * 100.0)|((count(description) / 54402) AS `description` * 100.0)|((count(sales_value) / 54402) AS `sales_value` * 100.0)|((count(sales_value_in_dollar) / 54402) AS `sales_value_in_dollar` * 100.0)|((count(currency) / 54402) AS `currency` * 100.0)|((count(sales_type) / 54402) AS `sales_type` * 100.0)|
# +---------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+---------------------------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------+
# |                                                                100.0|                                            100.0|                                                    100.0|                                                0.14889158486820336|                                     32.232270872394395|                                                  100.0|                                                                      100.0|                                99.99264732914232|                                                100.0|
# +---------------------------------------------------------------------+-------------------------------------------------+---------------------------------------------------------+-------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------+---------------------------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------+
#
# pc_excipient.csv
# +--------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+
# |((count(excipient_id) / 3385) AS `excipient_id` * 100.0)|((count(excipient_name) / 3385) AS `excipient_name` * 100.0)|((count(moment_updated) / 3385) AS `moment_updated` * 100.0)|
# +--------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+
# |                                                   100.0|                                                       100.0|                                                       100.0|
# +--------------------------------------------------------+------------------------------------------------------------+------------------------------------------------------------+
#
# pc_company.csv
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+
# |((count(company_id) / 3547) AS `company_id` * 100.0)|((count(name) / 3547) AS `name` * 100.0)|((count(synonym) / 3547) AS `synonym` * 100.0)|((count(address) / 3547) AS `address` * 100.0)|((count(city) / 3547) AS `city` * 100.0)|((count(US_state) / 3547) AS `US_state` * 100.0)|((count(country) / 3547) AS `country` * 100.0)|((count(company_website) / 3547) AS `company_website` * 100.0)|((count(telephone) / 3547) AS `telephone` * 100.0)|((count(year_founded) / 3547) AS `year_founded` * 100.0)|((count(employee_number) / 3547) AS `employee_number` * 100.0)|((count(moment_updated) / 3547) AS `moment_updated` * 100.0)|
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+
# |                                               100.0|                                   100.0|                             50.09867493656611|                                99.49252889766|                       99.57710741471666|                               30.10995207217367|                             99.88722864392444|                                             80.57513391598535|                                  92.1623907527488|                                       91.51395545531436|                                            14.942204680011278|                                                       100.0|
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+

# %%
colname = list(to_open.select('mvv').toPandas()['mvv']
)

# %%
import pyspark.sql.functions as F

for f in files:
    to_open = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv(path + f)
    colname = list(to_open.schema.names)
    if 'source' in colname:
        print(colname)
    if colname[0] == 'api_manufacturer':
        to_open.groupBy('source').agg(F.countDistinct(F.col('api'))).show(20, False)  
    if colname[0] == 'fdf_manufacturer':
        to_open.groupBy('source').agg(F.countDistinct(F.col('fdf'))).show(20, False)
# Out:
# ['api_manufacturer', 'source', 'duns_number', 'fei', 'api_manufacturer_address', 'country', 'api', 'unii_code', 'CAS_registry']
# +-------------------+-------------------+
# |source             |count(DISTINCT api)|
# +-------------------+-------------------+
# |China Regulatory   |2645               |
# |FDA DMF            |11970              |
# |CEP/COS Certificate|2410               |
# |New Zealand Medsafe|2522               |
# |China Api          |827                |
# |India DMF          |1559               |
# |FDA US Label       |1432               |
# |Company Website    |19418              |
# +-------------------+-------------------+
#
# ['fdf_manufacturer', 'source', 'duns_number', 'fei', 'fdf_manufacturer_address', 'country', 'product_name', 'NDC_code', 'fdf', 'applicant', 'marketing_category_name', 'dosage_form', 'route_of_administration', 'excipient_name', 'excipient_synonym']
# +-------------------+-------------------+
# |source             |count(DISTINCT fdf)|
# +-------------------+-------------------+
# |New Zealand Medsafe|2433               |
# |Japan (PMDA)       |5432               |
# |FDA US Label       |3240               |
# +-------------------+-------------------+

# %%
# Import PySpark Library
from pyspark.sql import SparkSession
# Initialize a Spark Session
spark = SparkSession.builder.getOrCreate()
# Edit the default Config for the "eagerEval" of the Spark Session 
# Reason: Improve the formatting of table printout
# Assumption: These options are on by default, and are only meant to help optimized certain processes in Spark
# Note: Only works for 'last line' outputs, but not for print out commands 
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)

# %%
api_manufacturer = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/api_manufacturer.csv")

# %%
api_manufacturer
# Out:
# +--------------------+-------------------+-----------+----+------------------------+--------------+--------------------+---------+------------+
# |    api_manufacturer|             source|duns_number| fei|api_manufacturer_address|       country|                 api|unii_code|CAS_registry|
# +--------------------+-------------------+-----------+----+------------------------+--------------+--------------------+---------+------------+
# |Merck KGaA DE 642...|CEP/COS Certificate|       null|null|                    null|       Germany|       Ascorbic acid|     null|        null|
# |DR. REDDY\'S LABO...|CEP/COS Certificate|       null|null|                    null|         India|Diltiazem hydroch...|     null|        null|
# |Janssen Pharmaceu...|CEP/COS Certificate|       null|null|                    null|       Ireland|        Ketoconazole|     null|        null|
# |KDL Biotech Limit...|CEP/COS Certificate|       null|null|                    null|         India|Amoxicillin trihy...|     null|        null|
# |KDL Biotech Limit...|CEP/COS Certificate|       null|null|                    null|         India|  Cloxacillin sodium|     null|        null|
# |KW Pfannenschmidt...|CEP/COS Certificate|       null|null|                    null|       Germany|        Theophylline|     null|        null|
# |Teva Group - Bulk...|CEP/COS Certificate|       null|null|                    null|        Israel|            Atenolol|     null|        null|
# |Amino GmbH DE 383...|CEP/COS Certificate|       null|null|                    null|       Germany|          Isoleucine|     null|        null|
# |Amifarma S.L. ES ...|CEP/COS Certificate|       null|null|                    null|         Spain|Cefazolin sodium ...|     null|        null|
# |Klinge Pharma  & ...|CEP/COS Certificate|       null|null|                    null|       Ireland|   Diclofenac sodium|     null|        null|
# |Hexal Syntech Gmb...|CEP/COS Certificate|       null|null|                    null|       Germany|          Alprazolam|     null|        null|
# |Diosynth BV NL 53...|CEP/COS Certificate|       null|null|                    null|   Netherlands|           Midazolam|     null|        null|
# |Janssen Pharmaceu...|CEP/COS Certificate|       null|null|                    null|       Ireland|  Miconazole nitrate|     null|        null|
# |Eli Lilly SA IE C...|CEP/COS Certificate|       null|null|                    null|       Ireland|Fluoxetine hydroc...|     null|        null|
# |PCAS FR 91160 Lon...|CEP/COS Certificate|       null|null|                    null|        France|Betahistine mesilate|     null|        null|
# |DSM Nutritional P...|CEP/COS Certificate|       null|null|                    null|   Switzerland|          Riboflavin|     null|        null|
# |NIPPON KAYAKU CO....|CEP/COS Certificate|       null|null|                    null|         Japan|Minocycline hydro...|     null|        null|
# |Siegfried Ltd CH ...|CEP/COS Certificate|       null|null|                    null|   Switzerland|          Nimodipine|     null|        null|
# |Whyte Chemicals G...|CEP/COS Certificate|       null|null|                    null|United Kingdom|Isosorbide mononi...|     null|        null|
# |Janssen Pharmaceu...|CEP/COS Certificate|       null|null|                    null|       Ireland|         Domperidone|     null|        null|
# +--------------------+-------------------+-----------+----+------------------------+--------------+--------------------+---------+------------+
# only showing top 20 rows

# %%
api_manufacturer.agg(*(100.0*(F.count(F.col(c))/api_manufacturer.count()).alias(c) for c in api_manufacturer.columns))
# Out:
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+
# |((count(api_manufacturer) / 110387) AS `api_manufacturer` * 100.0)|((count(source) / 110387) AS `source` * 100.0)|((count(duns_number) / 110387) AS `duns_number` * 100.0)|((count(fei) / 110387) AS `fei` * 100.0)|((count(api_manufacturer_address) / 110387) AS `api_manufacturer_address` * 100.0)|((count(country) / 110387) AS `country` * 100.0)|((count(api) / 110387) AS `api` * 100.0)|((count(unii_code) / 110387) AS `unii_code` * 100.0)|((count(CAS_registry) / 110387) AS `CAS_registry` * 100.0)|
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+
# |                                                 99.97825830940238|                             99.97825830940238|                                      2.3481025845434695|                       2.176886771087175|                                                                 73.20517814597733|                               92.26811128121972|                       99.97191698297807|                                   2.332702220370152|                                        1.7656064572821075|
# +------------------------------------------------------------------+----------------------------------------------+--------------------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------------+----------------------------------------------------------+

# %%
# some address has no country info
null_country = api_manufacturer.filter(api_manufacturer.country.isNull())
null_country
# Out:
# +--------------------+---------+-----------+----+------------------------+-------+--------------------+---------+------------+
# |    api_manufacturer|   source|duns_number| fei|api_manufacturer_address|country|                 api|unii_code|CAS_registry|
# +--------------------+---------+-----------+----+------------------------+-------+--------------------+---------+------------+
# |M/s.RA Chem Pharm...|India DMF|       null|null|                    null|   null|  Doxazosin Mesylate|     null|        null|
# |M/s. Indoco Remed...|India DMF|       null|null|                    null|   null|     Olopatadine HCl|     null|        null|
# |M/s. Indoco Remed...|India DMF|       null|null|                    null|   null|    Bromfenac Sodium|     null|        null|
# |M/s. Parabolic Dr...|India DMF|       null|null|                    null|   null| Cefixime Trihydrate|     null|        null|
# |M/s. Parabolic Dr...|India DMF|       null|null|                    null|   null|Cefpodoxime Proxetil|     null|        null|
# |M/s. Parabolic Dr...|India DMF|       null|null|                    null|   null|   Cefuroxime Axetil|     null|        null|
# |M/s. Parabolic Dr...|India DMF|       null|null|                    null|   null|            Cefdinir|     null|        null|
# |M/s. Parabolic Dr...|India DMF|       null|null|                    null|   null|           Cefprozil|     null|        null|
# |M/s. Vitalife Lab...|India DMF|       null|null|                    null|   null|Ropinirole Hydroc...|     null|        null|
# |M/s. Sharp Global...|India DMF|       null|null|                    null|   null|             Menthol|     null|        null|
# |M/s. Morepen Labo...|India DMF|       null|null|                    null|   null|          Loratadine|     null|        null|
# |M/s. Morepen Labo...|India DMF|       null|null|                    null|   null|       Desloratidine|     null|        null|
# |M/s. Morepen Labo...|India DMF|       null|null|                    null|   null|  Montelukast Sodium|     null|        null|
# |M/s. BEC Chemical...|India DMF|       null|null|                    null|   null|          Ketoprofen|     null|        null|
# |M/s. BEC Chemical...|India DMF|       null|null|                    null|   null|          Mesalamine|     null|        null|
# |M/s. BEC Chemical...|India DMF|       null|null|                    null|   null|          Mesalazine|     null|        null|
# |M/s. Unichem Lab....|India DMF|       null|null|                    null|   null| Amlodipine Besylate|     null|        null|
# |M/s. Unichem Lab....|India DMF|       null|null|                    null|   null|         Nateglinide|     null|        null|
# |M/s. Unichem Lab....|India DMF|       null|null|                    null|   null|       Memantine HCL|     null|        null|
# |M/s. Unichem Lab....|India DMF|       null|null|                    null|   null|       Alfuzosin HCL|     null|        null|
# +--------------------+---------+-----------+----+------------------------+-------+--------------------+---------+------------+
# only showing top 20 rows

# %%
# There are mixed upper and lower case in name
# Not every API has UNII code or Cas Number
# Not every address is availanble 

not_null_unii = api_manufacturer.filter(api_manufacturer.unii_code.isNotNull())
not_null_unii
# Out:
# +--------------------+------------+-----------+----------+------------------------+-------+--------------------+----------+------------+
# |    api_manufacturer|      source|duns_number|       fei|api_manufacturer_address|country|                 api| unii_code|CAS_registry|
# +--------------------+------------+-----------+----------+------------------------+-------+--------------------+----------+------------+
# |        HOMEODEL INC|FDA US Label|  259068237|3008740602|                    null|   null| ANTIMONY TRISULFIDE|F79059A38U|        null|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null|ADENOSINE TRIPHOS...|5L51B4DR1G|    987-65-5|
# |Beecham Pharmaceu...|FDA US Label|  595132580|3003469490|                    null|   null|         AMOXICILLIN|804826J2HU|  26787-78-0|
# |LABORATORIOS JAYO...|FDA US Label|  979312485|      null|                    null|   null|               WATER|059QF0KO0R|   7732-18-5|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null| CONVALLARIA MAJALIS|QHH4HVF5QE|        null|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null| BETULA PENDULA BARK|40S83Y133C|        null|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null|             PYRROLE|86S1ZD6L2C|        null|
# |           Olon, SpA|FDA US Label|  543029958|3002806373|                    null|   null|doxorubicin hydro...|82F2G7BL4E|  25316-40-9|
# |Aurobindo Pharma ...|FDA US Label|  918917662|3004086884|                    null|   null|clopidogrel bisul...|08I79HTP27| 120202-66-6|
# |Janssen Pharmaceu...|FDA US Label|  080236951|   1033845|                    null|   null|tapentadol hydroc...|71204KII53| 175591-09-0|
# |       Noramco, Inc.|FDA US Label|  057234486|3012286613|                    null|   null|tapentadol hydroc...|71204KII53| 175591-09-0|
# |     PCAS Finland Oy|FDA US Label|  369587311|3003469991|                    null|   null|            BACLOFEN|H789N3FKE8|   1134-47-0|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null|SELENICEREUS RAND...|7114SV0MYK|        null|
# |      Aspen Oss B.V.|FDA US Label|  491013870|3010414279|                    null|   null|         MIRTAZAPINE|A051Q2099Q|  85650-52-8|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null|PHYTOLACCA AMERIC...|11E6VI8VEG|        null|
# |Gland Pharma Limited|FDA US Label|  918601238|3002647489|                    null|   null|ESMOLOL HYDROCHLO...|V05260LC8D|  81161-17-3|
# |      Aspen Oss B.V.|FDA US Label|  491013870|3010414279|                    null|   null|        etonogestrel|304GTH6RNH|  54048-10-1|
# |    Apotheca Company|FDA US Label|  844330915|   1931484|                    null|   null|    AETHUSA CYNAPIUM|M6936L953C|        null|
# |Aurobindo Pharma ...|FDA US Label|  918917662|3004086884|                    null|   null|SERTRALINE HYDROC...|UTI8907Y6X|  79559-97-0|
# |Aurobindo Pharma ...|FDA US Label|  918917647|3004021253|                    null|   null|           GLYBURIDE|SX6K58TVWC|  10238-21-8|
# +--------------------+------------+-----------+----------+------------------------+-------+--------------------+----------+------------+
# only showing top 20 rows

# %%
def display_colvalue(dataset, colname):
    dataset.select(colname).distinct().show(20, False)

# %%
china_reg = api_manufacturer.filter(api_manufacturer.source == 'China Regulatory')
china_reg
# Out:
# +--------------------+----------------+-----------+----+------------------------+-------+---------------------+---------+------------+
# |    api_manufacturer|          source|duns_number| fei|api_manufacturer_address|country|                  api|unii_code|CAS_registry|
# +--------------------+----------------+-----------+----+------------------------+-------+---------------------+---------+------------+
# |Evonik Rexim(Nann...|China Regulatory|       null|null|    10 Wenjiang Road,...|  China| α-ketoleucine cal...|     null|        null|
# |Hebei JiuPai Phar...|China Regulatory|       null|null|    Sanxia road, econ...|  China| α-Ketophenylalani...|     null|        null|
# |Hebei JiuPai Phar...|China Regulatory|       null|null|    Sanxia road, econ...|  China| α-Ketoleucine Cal...|     null|        null|
# |CHANGZHOU  YABANG...|China Regulatory|       null|null|    LIANGCHANG EAST R...|  China|            α-Asarone|     null|        null|
# |Cisen  Pharmaceut...|China Regulatory|       null|null|    Tongji  Tech  Ind...|  China|Ｃycloclenbuterol ...|     null|        null|
# |Zhejiang Hisun Ph...|China Regulatory|       null|null|    No.46,Waisha Road...|  China|         zolmitriptan|     null|        null|
# |Chongqing Lummy p...|China Regulatory|       null|null|    No. 2, Hua’nan 4t...|  China|         voriconazole|     null|        null|
# |Jiangsu Wuzhong P...|China Regulatory|       null|null|    No.561 SixFeng Ro...|  China|           vitamin D3|     null|        null|
# |Guangdong Xianqia...|China Regulatory|       null|null|    Gongye Road,Congh...|  China|            tiopronin|     null|        null|
# |Tangshan City Rui...|China Regulatory|       null|null|    Tangshan City Yut...|  China| terbinafine hydro...|     null|        null|
# |Zhejiang Hisun Ph...|China Regulatory|       null|null|    No.46,Waisha Road...|  China|    sulbactam  Sodium|     null|        null|
# |HEBEI SHENGXUE DA...|China Regulatory|       null|null|    No.17  FUQIANGXI ...|  China| streptomycin sulp...|     null|        null|
# |HNG  Chembio  Pha...|China Regulatory|       null|null|    1.XiHu  District ...|  China| sterile Active Ph...|     null|        null|
# |SJZ RUIXUE PHARMA...|China Regulatory|       null|null|    Shijiazhuang Econ...|  China|             sorbitol|     null|        null|
# |Tianjin Haiguang ...|China Regulatory|       null|null|    No. 5 The Seventh...|  China|      sodium chloride|     null|        null|
# |Sichunan Medco Ph...|China Regulatory|       null|null|    East Jinhe Koad,S...|  China|             silymarn|     null|        null|
# |Suzhou Homesun Ph...|China Regulatory|       null|null|    No.12, west Xiexi...|  China|           salbutamol|     null|        null|
# |Changzheng-Cinkat...|China Regulatory|       null|null|    No.2,Dongwu South...|  China| rimetazidine Hydr...|     null|        null|
# |Zhejiang Sixian P...|China Regulatory|       null|null|    Industrial Zone,Q...|  China|            rifaximin|     null|        null|
# |CHANGZHOU  YABANG...|China Regulatory|       null|null|    LIANGCHANG EAST R...|  China|         prulifoxacin|     null|        null|
# +--------------------+----------------+-----------+----+------------------------+-------+---------------------+---------+------------+
# only showing top 20 rows

# %%
china_reg.select('api_manufacturer_address').show(20, False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |api_manufacturer_address                                                                                                                                                              |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |10 Wenjiang Road,Wuming County,Nanning，Guangxi                                                                                                                                       |
# |Sanxia road, economy teconology area of shijiazhuang                                                                                                                                  |
# |Sanxia road, economy teconology area of shijiazhuang                                                                                                                                  |
# |LIANGCHANG EAST ROAD 6# ，JINTAN JIANGSU ，CHINA                                                                                                                                      |
# |Tongji  Tech  Industry  garden， Jining  High  &New  Technology  Industries  Development  Zone                                                                                        |
# |No.46,Waisha Road,Jiaojiang District, Taizhou City,Zhejiang;No.1,Haizheng Dadao,Jiaojiang District, Taizhou City,Zhejiang；No.56,Binhai Road,Jiaojiang District, Taizhou City,Zhejiang|
# |No. 2, Hua’nan 4th branch road of chemical industry are, Chongqing(changshou); No. 8, Yueji Road, Nan’an Region of Chongqing                                                          |
# |No.561 SixFeng Road,Hedong Industrial Park,Wuzhong Economic Development Zone,Suzhou                                                                                                   |
# |Gongye Road,Conghua Economic Development Zone, Guangzhou                                                                                                                              |
# |Tangshan City Yutian County Tangzitou Town zhongjiashan                                                                                                                               |
# |No.46,Waisha Road,Jiaojiang District, Taizhou City,Zhejiang;No.1,Haizheng Dadao,Jiaojiang District, Taizhou City,Zhejiang；No.56,Binhai Road,Jiaojiang District, Taizhou City,Zhejiang|
# |No.17  FUQIANGXI ROAD LUANCHENG  SHIJIAZHUANG 051430, CHINA                                                                                                                           |
# |1.XiHu  District  Changde  City  Hunan  Province ；2. Changsha Bio & Information Industry Park South-cycle Park Road, Hunan Province                                                  |
# |Shijiazhuang Econmic and Technological Development Zone,Qingyuan Street No.6                                                                                                          |
# |No. 5 The Seventh Street TEDA Tianjin                                                                                                                                                 |
# |East Jinhe Koad,Shifang,Sichuan.                                                                                                                                                      |
# |No.12, west Xiexin road, Taicang Port Development Zone, Taicang city, Jiangsu Province, China.                                                                                        |
# |No.2,Dongwu South Road, Suzhou, Jiangsu                                                                                                                                               |
# |Industrial Zone,Qixian Town,Shaoxing,Zhejiang                                                                                                                                         |
# |LIANGCHANG EAST ROAD 6# ，JINTAN JIANGSU ，CHINA                                                                                                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
company_web = api_manufacturer.filter(api_manufacturer.source == 'Company Website')
company_web.select('api_manufacturer','api_manufacturer_address').show(20, False)
# Out:
# +--------------------------+----------------------------------------------------------------------------------+
# |api_manufacturer          |api_manufacturer_address                                                          |
# +--------------------------+----------------------------------------------------------------------------------+
# |APOTEX PHARMACHEM INC     |11, 34, 50 Spalding Drive||Brantford, Ontario, Canada N3T 6B8                     |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APICORE LLC               |49 Napoleon Ct. Somerset NJ 08520 United States                                   |
# |Ameya Laboratories Limited|A-49, Madhura Nagar, Vengalarao Nagar,||Hyderabad - 500 038||Andhra Pradesh, INDIA|
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# |APOTEX PHARMACHEM INC     |null                                                                              |
# +--------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
FDADMF = api_manufacturer.filter(api_manufacturer.source == 'FDA DMF')
FDADMF
# Out:
# +--------------------+-------+-----------+----+------------------------+--------------------+--------------------+---------+------------+
# |    api_manufacturer| source|duns_number| fei|api_manufacturer_address|             country|                 api|unii_code|CAS_registry|
# +--------------------+-------+-----------+----+------------------------+--------------------+--------------------+---------+------------+
# |          SPECGX LLC|FDA DMF|       null|null|                    null|United States of ...|  PARZONE BITARTRATE|     null|        null|
# |FIS FABBRICA ITAL...|FDA DMF|       null|null|    Via Massimo D'Ant...|               Italy|NITROFURANTOIN & ...|     null|        null|
# |FIS FABBRICA ITAL...|FDA DMF|       null|null|    Via Massimo D'Ant...|               Italy|CHLORDIAZEPOXIDE HCL|     null|        null|
# |CAMBREX PROFARMAC...|FDA DMF|       null|null|    VIA EUGENIO CURIE...|               Italy|CHLORDIAZEPOXIDE ...|     null|        null|
# |CAMBREX PROFARMAC...|FDA DMF|       null|null|    Via Curiel, 34 Pa...|               Italy| HYDROCHLOROTHIAZIDE|     null|        null|
# |    AJINOMOTO CO INC|FDA DMF|       null|null|    450 Morodomichomo...|United States of ...| AMINO ACID PRODUCTS|     null|        null|
# |   SIEGFRIED USA LLC|FDA DMF|       null|null|    33 Industrial Par...|United States of ...|          BUTALBITAL|     null|        null|
# |FMC LITHIUM SUB F...|FDA DMF|       null|null|                    null|                null|   LITHIUM CARBONATE|     null|        null|
# |UNION CARBIDE COR...|FDA DMF|       null|null|                    null|              France|CARBOWAX POLYETHY...|     null|        null|
# |PHARMACIA AND UPJ...|FDA DMF|       null|null|                    null|               Spain|HYDROCORTISONE MI...|     null|        null|
# |PHARMACIA AND UPJ...|FDA DMF|       null|null|                    null|            Colombia|PROGESTERONE MICR...|     null|        null|
# |DDP SPECIALTY ELE...|FDA DMF|       null|null|                    null|United States of ...|DOW CORNING Q7-22...|     null|        null|
# |CAMBREX PROFARMAC...|FDA DMF|       null|null|    Via Curiel, 34 Pa...|               Italy|            DIAZEPAM|     null|        null|
# |       SANOFI CHIMIE|FDA DMF|       null|null|    Usine de producti...|              France|CHLORPROMAZINE HY...|     null|        null|
# |       SANOFI CHIMIE|FDA DMF|       null|null|    Usine de producti...|              France|       DEXAMETHASONE|     null|        null|
# |COPPERHEAD INVEST...|FDA DMF|       null|null|                    null|United States of ...|              SDM-17|     null|        null|
# |          SPECGX LLC|FDA DMF|       null|null|                    null|United States of ...|        NALOXONE HCL|     null|        null|
# |       SANOFI CHIMIE|FDA DMF|       null|null|    Usine de producti...|              France|    PROMETHAZINE HCL|     null|        null|
# |            BAYER AG|FDA DMF|       null|null|    Max-Dohrn-Strasse...|             Germany|    ETHINYLESTRADIOL|     null|        null|
# |DR REDDYS LABORAT...|FDA DMF|       null|null|                    null|                null|            NAPROXEN|     null|        null|
# +--------------------+-------+-----------+----+------------------------+--------------------+--------------------+---------+------------+
# only showing top 20 rows

# %%
api_pc_nonspl =  api_manufacturer.filter(api_manufacturer.source != 'FDA US Label')

# %% [markdown]
# ### unii and cas need to be mapped and added

# %%
fdf_manufacturer = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/fdf_manufacturer.csv")

# %%
fdf_manufacturer
# Out:
# +--------------------+-------------------+-----------+----+------------------------+-------+--------------------+--------+--------------------+---------+-----------------------+--------------------+-----------------------+--------------------+-----------------+
# |    fdf_manufacturer|             source|duns_number| fei|fdf_manufacturer_address|country|        product_name|NDC_code|                 fdf|applicant|marketing_category_name|         dosage_form|route_of_administration|      excipient_name|excipient_synonym|
# +--------------------+-------------------+-----------+----+------------------------+-------+--------------------+--------+--------------------+---------+-----------------------+--------------------+-----------------------+--------------------+-----------------+
# |  perrigo uk limited|New Zealand Medsafe|       null|null|    Perrigo UK Limite...|   null|    milk of magnesia|    null| Magnesium hydroxide|     null|                   null|              Tablet|                   Oral|Magnesium stearat...|             null|
# |merck sharp  dohm...|New Zealand Medsafe|       null|null|    Merck Sharp  Dohm...|   null|              maxalt|    null|Rizatriptan benzoate|     null|                   null|  Film coated tablet|                   Oral|Iron oxide red|La...|             null|
# |catalent uk swind...|New Zealand Medsafe|       null|null|    Catalent UK Swind...|   null|              maxalt|    null|Rizatriptan benzoate|     null|                   null|               Wafer|                   null|Aspartame|Gelatin...|             null|
# |catalent uk swind...|New Zealand Medsafe|       null|null|    Catalent UK Swind...|   null|         maxalt melt|    null|Rizatriptan benzoate|     null|                   null|               Wafer|                   null|Aspartame|Gelatin...|             null|
# |  astrazeneca uk ltd|New Zealand Medsafe|       null|null|    AstraZeneca UK Lt...|   null|fluothane anaesth...|    null|           Halothane|     null|                   null|Volatile liquid f...|             Inhalation|                null|             null|
# |merck sharp  dohm...|New Zealand Medsafe|       null|null|    Merck Sharp  Dohm...|   null|             aldomet|    null|Methyldopate hydr...|     null|                   null|Solution for inje...|              Injection|                null|             null|
# |rhonepoulenc sant...|New Zealand Medsafe|       null|null|    RhonePoulenc Sant...|   null|           rovamycin|    null|          Spiramycin|     null|                   null|              Tablet|                   Oral|                null|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|  codral pain relief|    null|Codeine phosphate...|     null|                   null|              Tablet|                   Oral|Magnesium stearat...|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|codral original c...|    null|Codeine phosphate...|     null|                   null|              Tablet|                   Oral|Ethanol|Hyprolose...|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|  codral cough syrup|    null|Dextromethorphan ...|     null|                   null|               Syrup|                   Oral|Ethanol as 95% v/...|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|codral original d...|    null|Codeine phosphate...|     null|                   null|              Tablet|                   Oral|Ethanol|Hyprolose...|             null|
# |bristolmyers squi...|New Zealand Medsafe|       null|null|    BristolMyers Squi...|   null|           fungizone|    null|      Amphotericin B|     null|                   null|Powder for injection|              Injection|Deoxycholic acid|...|             null|
# |piramal healthcar...|New Zealand Medsafe|       null|null|    Piramal Healthcar...|   null|             lomotil|    null|Atropine sulfate ...|     null|                   null|              Tablet|                   Oral|Acacia|Light liqu...|             null|
# |            bayer ag|New Zealand Medsafe|       null|null|    Bayer AG  KaiserW...|   null|          fabahistin|    null|Mebhydrolin napad...|     null|                   null|              Tablet|                   Oral|Gelatin|Lactose m...|             null|
# |almirall hermal gmbh|New Zealand Medsafe|       null|null|    Almirall Hermal G...|   null|clearasil pimple ...|    null|           Bentonite|     null|                   null|       Topical cream|                Topical|Carbomer 940|Dibu...|             null|
# |procter  gamble a...|New Zealand Medsafe|       null|null|    Procter  Gamble A...|   null|clearasil daily f...|    null|           Triclosan|     null|                   null|              Lotion|                Topical|Amaranth|C9-11 Al...|             null|
# |pharmacia  upjohn as|New Zealand Medsafe|       null|null|    Pharmacia  Upjohn...|   null|rheomacrodex in s...|    null|             Dextran|     null|                   null|Solution for infu...|              Injection|                null|             null|
# |pharmacia  upjohn as|New Zealand Medsafe|       null|null|    Pharmacia  Upjohn...|   null|rheomacrodex in d...|    null|             Dextran|     null|                   null|Solution for infu...|              Injection|                null|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|brondecon expecto...|    null|Choline theophyll...|     null|                   null|               Syrup|                   Oral|Amaranth|Anethole...|             null|
# |pfizer australia ...|New Zealand Medsafe|       null|null|    Pfizer Australia ...|   null|broncelix junior ...|    null|Choline theophyll...|     null|                   null|               Syrup|                   Oral|                null|             null|
# +--------------------+-------------------+-----------+----+------------------------+-------+--------------------+--------+--------------------+---------+-----------------------+--------------------+-----------------------+--------------------+-----------------+
# only showing top 20 rows

# %%
#fdf_manufacturer.filter(F.col('source')== 'New Zealand Medsafe').select('fdf').orderBy(F.length('fdf').desc()).show(20, False)
#fdf_manufacturer.filter((F.col('source')== 'New Zealand Medsafe') & (F.length('fdf') == 30)).select('fdf').orderBy(F.length('fdf').desc()).show(20, False)
fdf_manufacturer.filter((F.col('source')== 'New Zealand Medsafe') & (F.col('fdf').rlike('Betamethasone'))).select('fdf').orderBy(F.length('fdf').desc()).show(20, False)
#Betamethasone sodium phosphate
# Out:
# +---+
# |fdf|
# +---+
# +---+

# %%
display_colvalue(fdf_manufacturer, 'source')
# Out:
# +-------------------+
# |source             |
# +-------------------+
# |New Zealand Medsafe|
# |Japan (PMDA)       |
# |FDA US Label       |
# +-------------------+

# %%
fdf_manufacturer.agg(*(100.0*(F.count(F.col(c))/fdf_manufacturer.count()).alias(c) for c in fdf_manufacturer.columns))
# Out:
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+
# |((count(fdf_manufacturer) / 77561) AS `fdf_manufacturer` * 100.0)|((count(source) / 77561) AS `source` * 100.0)|((count(duns_number) / 77561) AS `duns_number` * 100.0)|((count(fei) / 77561) AS `fei` * 100.0)|((count(fdf_manufacturer_address) / 77561) AS `fdf_manufacturer_address` * 100.0)|((count(country) / 77561) AS `country` * 100.0)|((count(product_name) / 77561) AS `product_name` * 100.0)|((count(NDC_code) / 77561) AS `NDC_code` * 100.0)|((count(fdf) / 77561) AS `fdf` * 100.0)|((count(applicant) / 77561) AS `applicant` * 100.0)|((count(marketing_category_name) / 77561) AS `marketing_category_name` * 100.0)|((count(dosage_form) / 77561) AS `dosage_form` * 100.0)|((count(route_of_administration) / 77561) AS `route_of_administration` * 100.0)|((count(excipient_name) / 77561) AS `excipient_name` * 100.0)|((count(excipient_synonym) / 77561) AS `excipient_synonym` * 100.0)|
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+
# |                                                            100.0|                                        100.0|                                     61.698534057064755|                      52.71334820334962|                                                               38.300176635164576|                              18.62662936269517|                                        99.99742138445869|                               61.698534057064755|                                  100.0|                                  61.69982336483542|                                                             61.698534057064755|                                      88.54965768878688|                                                              79.36720774616109|                                            78.66066708784054|                                                 0.7439305836696277|
# +-----------------------------------------------------------------+---------------------------------------------+-------------------------------------------------------+---------------------------------------+---------------------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------------+-------------------------------------------------+---------------------------------------+---------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------+-------------------------------------------------------------------+

# %%
fdf_manufacturer.filter(fdf_manufacturer.source == 'Japan (PMDA)').show(20, False)
# Out:
# +---------------------------------------+------------+-----------+----+-----------------------------------------------------------------+-------+--------------------------------------+--------+----------------------------------------------------------------------------------+---------+-----------------------+-------------------------------------------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |fdf_manufacturer                       |source      |duns_number|fei |fdf_manufacturer_address                                         |country|product_name                          |NDC_code|fdf                                                                               |applicant|marketing_category_name|dosage_form                                            |route_of_administration|excipient_name                                                                                                                                                    |excipient_synonym|
# +---------------------------------------+------------+-----------+----+-----------------------------------------------------------------+-------+--------------------------------------+--------+----------------------------------------------------------------------------------+---------+-----------------------+-------------------------------------------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |Sumio Yakuhin Kogyo Co., Ltd.          |Japan (PMDA)|null       |null|Yubinbango101-0032, Chiyoda-ku, Tokyo Iwamotocho chome 13th No. 5|Japan  |0.2% - acrinol solution               |null    |Acrinol hydrate                                                                   |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |Nichi-Iko, Inc.                        |Japan (PMDA)|null       |null|Toyama Sogawa 1-chome No. 6 21                                   |Japan  |Sodium Azulene Sulfonate              |null    |Sodium azulene sulfonic acid (Sodium Azulene Sulfonate)                           |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |Dong Pharmaceutical Co., Ltd.          |Japan (PMDA)|null       |null|Toyama, Toyama Prefecture Mizuhashikaihatsu 277 No. 10           |Japan  |AZUGAGURU GARGLE LIQUID T 4%          |null    |Sodium azulene sulfonic acid hydrate(Sodium Gualenate Hydrate)                    |null     |null                   |null                                                   |null                   |Propylene glycol|macrogol 400|ethanol|benzethonium chloride|sodium hydrogen phosphate hydrate|l-menthol|fennel oil|pH adjusting agent                             |null             |
# |Materia Medica Pharmaceutical Co., Ltd.|Japan (PMDA)|null       |null|Nagoya Tempaku-ku Furukawa-cho, 125 address                      |Japan  |Arzumine Gargle liquid 1%             |null    |Sodium azulene sulfonic acid (Sodium Azulene Sulfonate)                           |null     |null                   |null                                                   |null                   |Glycerin|ethanol|macrogol 400|sodium edetate|sodium hydrogen phosphate|sodium dihydrogen phosphate anhydrous|l - menthol|peppermint oil                           |null             |
# |Horii Yakuhin Kogyo Co., Ltd.          |Japan (PMDA)|null       |null|Chuo-ku, Osaka-shi Uchiawaji-cho 1-chome No. 2 No. 6             |Japan  |VOWLO Powder for gargle 0.4%          |null    |Sodium azulene sulfonic acid hydrate(Sodium Gualenate Hydrate)                    |null     |null                   |null                                                   |null                   |Sodium hydrogen carbonate|lactose hydrate|l - menthol|povidone                                                                                                    |null             |
# |Ohara Pharmaceutical Industry Co., Ltd.|Japan (PMDA)|null       |null|Shiga Prefecture Koka Koka-cho Toriino 121-15                    |Japan  |LEUCON TABLETS 10mg                   |null    |Adenine (Adenine)                                                                 |null     |null                   |White-tablet                                           |null                   |Lactose hydrate|potato starch|talc|magnesium stearate                                                                                                             |null             |
# |Ohara Pharmaceutical Industry Co., Ltd.|Japan (PMDA)|null       |null|Shiga Prefecture Koka Koka-cho Toriino 121-15                    |Japan  |LEUCON INJECTION                      |null    |Adenine (Adenine)                                                                 |null     |null                   |Colorless clear-Injection                              |null                   |null                                                                                                                                                              |null             |
# |Nippon eyedrops Institute              |Japan (PMDA)|null       |null|Nagoya, Minami-ku, Nishisakura cho address 76                    |Japan  |Nitten ATROPINE Ophthalmic Solution 1%|null    |Atropine sulfate hydrate Atropine Sulfate Hydrate                                 |null     |null                   |Clear and colorless sterile aqueous ophthalmic solution|null                   |Sodium bisulfite|benzalkonium chloride|monosodium phosphate (crystalline)|sodium phosphate dibasic (anhydrous)|isotonic agents                                    |null             |
# |Fuso Pharmaceutical Industries Ltd.    |Japan (PMDA)|null       |null|Osaka Joto-ku Morinomiya chome No. 3 No. 11                      |Japan  |Atropine Sulfate Injection            |null    |Atropine sulfate hydrate (atropine sulfate)                                       |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |Teikoku Seiyaku Co., Ltd.              |Japan (PMDA)|null       |null|Kagawa Prefecture Higashikagawa Sanbonmatsu 567 address          |Japan  |VISDERM OINTMENT 0.1%                 |null    |Amcinonide (Amcinonide) [JAN]                                                     |null     |null                   |null                                                   |null                   |Propylene carbonate|ethylene carbonate|cetanol|polyethylene glycol monostearate|propylene glycol|butyl hydroxy anisole|propyl gallate|citric acid|white petrolatum|null             |
# |Fuji Pharma Co., Ltd.                  |Japan (PMDA)|null       |null|Toyama, Toyama Prefecture Mizuhashi Tsujikedo 1515 address       |Japan  |Harizon tablets 100mg                 |null    |Amphotericin B (Amphotericin B)                                                   |null     |null                   |Naked tablet of yellow                                 |null                   |Lactose hydrate  Hydroxypropyl starch  Low-substituted hydroxypropyl cellulose  Hydroxypropylcellulose  Magnesium stearate                                        |null             |
# |Nipuropatchi Co., Ltd.                 |Japan (PMDA)|null       |null|Kasukabe, Saitama Prefecture Nan'ei-cho, 8 address 1             |Japan  |ALIMEZINE SYRUP                       |null    |alimemazine tartrate (trimeprazine tartrate)(Alimemazine tartrate)                |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |Yamada Pharmaceutical Co., Ltd.        |Japan (PMDA)|null       |null|Sumida-ku, Tokyo Higashikomagata 1-14-1                          |Japan  |Usunon Solution 10%                   |null    |Hydrochloric acid alkyldiaminoethylglycine                                        |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |KenSakae Pharmaceutical Co., Ltd.      |Japan (PMDA)|null       |null|Chuo-ku, Osaka Fushimi-cho 2-chome, No. 5 No. 8                  |Japan  |SATENIDIN SOLUTION 0.1                |null    |Hydrochloric acid alkyldiaminoethylglycine(Alkyldiaminoethylglycine Hydrochloride)|null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |ASKA Pharmaceutical Co., Ltd.          |Japan (PMDA)|null       |null|Shibaura, Minato-ku, Tokyo chome No. 5 No. 1                     |Japan  |ISALOPAN EXTERNAL POWDER 6%           |null    |Arukurokisaalcloxa [JAN]                                                          |null     |null                   |White powder (topical)                                 |null                   |Magnesium carbonate|corn starch|ethyl parahydroxybenzoate                                                                                                         |null             |
# |Fuji Pharma Co., Ltd.                  |Japan (PMDA)|null       |null|Toyama, Toyama Prefecture Mizuhashi Tsujikedo 1515 address       |Japan  |Tarumea TALMEA                        |null    |Al Black betamethasone propionate(Alclometasone Dipropionate) (JAN)               |null     |null                   |null                                                   |null                   |Sorbitan sesquioleate ester  Propylene glycol  Benzyl alcohol  Liquid paraffin  White petrolatum                                                                  |null             |
# |Taisho Pharmaceutical Co., Ltd.        |Japan (PMDA)|null       |null|Toshima-ku, Tokyo Takada 3-24-1                                  |Japan  |Palux inj. 5μg                        |null    |Alprostadil (JAN)alprostadil (JAN, INN)                                           |null     |null                   |ampoule                                                |null                   |Purified soybean oil 100mg  Highly purified egg yolk lecithin 18mg  Oleic acid 2.4mg  Concentrated glycerin 22.1mg  Sodium hydroxide appropriate amount           |null             |
# |Sawai Pharmaceutical Co., Ltd.         |Japan (PMDA)|null       |null|Yodogawa-ku, Osaka Miyahara 5-chome, 2-30                        |Japan  |ALPROSTADIL                           |null    |Alprostadil (Alprostadil)                                                         |null     |null                   |null                                                   |null                   |null                                                                                                                                                              |null             |
# |* Nippon Boehringer Ingelheim Co., Ltd.|Japan (PMDA)|null       |null|Osaki, Shinagawa-ku, Tokyo 2 chome No. 1                         |Japan  |Mucosal Tablets 15mg                  |null    |Ambroxol hydrochloride (JAN)Ambroxol Hydrochloride (JAN)Ambroxol (INN)            |null     |null                   |White plain tablet (dividing line)                     |null                   |Lactose hydrate|corn starch|light anhydrous silicic acid|magnesium stearate                                                                                       |null             |
# |Teijin Pharma Limited                  |Japan (PMDA)|null       |null|* Chiyoda-ku, Tokyo Kasumigaseki 3-chome No. 2 No. 1             |Japan  |Mucosolvan Tablet 15mg                |null    |Ambroxol hydrochloride (Ambroxol Hydrochloride)                                   |null     |null                   |tablet                                                 |null                   |lactose  Corn starch  Light anhydrous silicic acid  Magnesium stearate                                                                                            |null             |
# +---------------------------------------+------------+-----------+----+-----------------------------------------------------------------+-------+--------------------------------------+--------+----------------------------------------------------------------------------------+---------+-----------------------+-------------------------------------------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### pc_branch is for relationship of many different kinds, from
# branch_id 6 is API or biological sup

# %%
pc_branch = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_branch.csv")

# %%
pc_branch
# Out:
# +---------+------------+--------------------+--------------------+---------+-----------+---------+--------------------+--------------------+--------------------+-----------+
# |branch_id|abbreviation|         branch_name|      branch_synonym|full_name|explanation|hyperlink|            top_page|                type|             hide_in|   dds_type|
# +---------+------------+--------------------+--------------------+---------+-----------+---------+--------------------+--------------------+--------------------+-----------+
# |        1|        null|       DRUG DELIVERY|                null|     null|       null|     null|static_top/drug_d...|       drug delivery|                null|       null|
# |        2|        null|PHARMA & BIOTECHN...|                null|     null|       null|     null|static_top/pharma...|pharma/biotechnology|                null|formulation|
# |        3|        null|    Pharma Equipment|                null|     null|       null|     null|                null|               links|                null|formulation|
# |        4|        null|Pharmaceutical Se...|                null|     null|       null|     null|                null|               links|technology/pharmabio|formulation|
# |        5|        null|Pharmaceutical Se...|                null|     null|       null|     null|                null|               links|                null|formulation|
# |        6|        null|API/Biologics Sup...|Active Pharmaceut...|     null|       null|     null|                null|               links|                null|formulation|
# |        7|        null|Pharmaceutical Ex...|                null|     null|       null|     null|                null|               links|                null|formulation|
# |        9|        null|                ORAL|                null|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       10|        null|           INJECTION|          PARENTERAL|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       11|        null|                SKIN|           CUTANEOUS|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       12|        null|          INHALATION|     Pulmonary||Lung|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       13|        null|               BRAIN|Intracerebral Del...|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       14|        null|Nucleic Acid Deli...|       Gene Delivery|     null|       null|     null|                null|       drug delivery|technology/pharma...|formulation|
# |       15|        null|          OPHTHALMIC|         Eye||Ocular|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       17|        null|             VAGINAL|                null|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       20|        null|              RECTAL|                null|     null|       null|     null|                null|       drug delivery|                null|      route|
# |       22|        null|Oral Modified Rel...|Oral Long Acting|...|     null|       null|     null|                null|       drug delivery|                null|formulation|
# |       23|        null|        Effervescent|                null|     null|       null|     null|                null|       drug delivery|                null|formulation|
# |       24|        null|Oral Peptide/Prot...|Oral Large Molecu...|     null|       null|     null|                null|       drug delivery|                null|formulation|
# |       25|        null|    Oral Enhanced BA|Oral Increased Ab...|     null|       null|     null|                null|       drug delivery|                null|formulation|
# +---------+------------+--------------------+--------------------+---------+-----------+---------+--------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ### Branch Hierarchy is a parent child relationship lookup table

# %%
bh = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/Branch_Hierarchy.csv")

# %%
## get unique count of parent id and child id

# %% [markdown]
# ### number of api

# %%
import pyspark.sql.functions as F
api_manufacturer.agg(F.countDistinct(F.lower(F.col('api'))))
# Out:
# +--------------------------+
# |count(DISTINCT lower(api))|
# +--------------------------+
# |                     32500|
# +--------------------------+

# %%
api_pc_nonspl.agg(F.countDistinct(F.col('api')))
# Out:
# +-------------------+
# |count(DISTINCT api)|
# +-------------------+
# |              36754|
# +-------------------+

# %%
#read newport from csv file
newport = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ",").csv("/home/zhengrongma/supply_chain_project/data/newport/USP_API_Manufacturers__March2020Delivery_v2.0_wFEI.csv")

# %%
newport
# Out:
# +-----------------+----------+-------------+----------+----------------------------+--------------------+----------+--------------------+------------------+----------+-----+-----------+-------+--------------------+--------------------+-------------+------------------------+------------+----------+----------+-------------------+----------------------+--------------------------+-----------------------+
# |       GROUP NAME|GROUP CITY|GROUP COUNTRY|GROUP TYPE|NEWPORT CORPORATE API RATING|        COMPANY NAME|FEI NUMBER|               ADDR1|             ADDR2|POSTALCODE| CITY|      STATE|COUNTRY|   ACTIVE INGREDIENT|MANUFACTURING STATUS|ACTIVE US DMF|AVAILABLE FOR REF US DMF|JAPANESE DMF|KOREAN DMF|ACTIVE COS|FDA INSPECTION DATE|GDUFA FEE PAYMENT DATE|FACILITY REGISTRATION DATE|FDA WARNING LETTER DATE|
# +-----------------+----------+-------------+----------+----------------------------+--------------------+----------+--------------------+------------------+----------+-----+-----------+-------+--------------------+--------------------+-------------+------------------------+------------+----------+----------+-------------------+----------------------+--------------------------+-----------------------+
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|     ferrous sulfate|Unconfirmed API a...|            1|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|   citicoline sodium|Commercially Avai...|            0|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|metronidazole ben...|Commercially Avai...|            0|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|     thionordiazepam|   Not Manufacturing|            0|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|          nordazepam|   Not Manufacturing|            0|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|   Acharya Chemicals|3010957801|W-41, MIDC, Indl....|Ambarnath District|    421501|Thane|Maharashtra|  India|desipramine hydro...|   Not Manufacturing|            0|                       0|           0|         0|         0|       6/24/16 0:00|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|clomipramine hydr...|Commercially Avai...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|           reserpine|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|            diazepam|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|          halquinols|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|        trimipramine|Unconfirmed API a...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|          zidovudine|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|   methyl nicotinate|Commercially Avai...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|   benzyl nicotinate|Commercially Avai...|            0|                       0|           1|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|chlordiazepoxide ...|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|imipramine hydroc...|Unconfirmed API a...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|          nicorandil|Commercially Avai...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|    chlordiazepoxide|Unconfirmed API a...|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|          nifedipine|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# |Acharya Chemicals|    Mumbai|        India|       API|            Potential Future|Herbert Brown Pha...|      #N/A|W-258, M.I.D.C. P...|   Dombivli (East)|   421 203|Thane|Maharashtra|  India|           stavudine|   Not Manufacturing|            0|                       0|           0|         0|         0|               null|                  null|                      null|                   null|
# +-----------------+----------+-------------+----------+----------------------------+--------------------+----------+--------------------+------------------+----------+-----+-----------+-------+--------------------+--------------------+-------------+------------------------+------------+----------+----------+-------------------+----------------------+--------------------------+-----------------------+
# only showing top 20 rows

# %%
newport.agg(f.countDistinct(f.col('ACTIVE INGREDIENT')))
# Out:
# +---------------------------------+
# |count(DISTINCT ACTIVE INGREDIENT)|
# +---------------------------------+
# |                             6660|
# +---------------------------------+

# %%
#lst_pc_api = api_manufacturer.select('api').collect()
lst_pc_api = list(api_manufacturer.select('api').toPandas()['api'] )
lst_np_api = list(newport.select('ACTIVE INGREDIENT').toPandas()['ACTIVE INGREDIENT'] )

# %%
lst_common = [item for item in lst_pc_api if item in lst_np_api ]

# %%
print(len(lst_common))
# Out:
# 1603

# %%
lst_name = newport.schema.names

# %%
lst_name
# Out:
# ['GROUP NAME',
#  'GROUP CITY',
#  'GROUP COUNTRY',
#  'GROUP TYPE',
#  'NEWPORT CORPORATE API RATING',
#  'COMPANY NAME',
#  'FEI NUMBER',
#  'ADDR1',
#  'ADDR2',
#  'POSTALCODE',
#  'CITY',
#  'STATE',
#  'COUNTRY',
#  'ACTIVE INGREDIENT',
#  'MANUFACTURING STATUS',
#  'ACTIVE US DMF',
#  'AVAILABLE FOR REF US DMF',
#  'JAPANESE DMF',
#  'KOREAN DMF',
#  'ACTIVE COS',
#  'FDA INSPECTION DATE',
#  'GDUFA FEE PAYMENT DATE',
#  'FACILITY REGISTRATION DATE',
#  'FDA WARNING LETTER DATE']

# %%
lst_FDADMF = list(set(FDADMF.select('api_manufacturer').toPandas()['api_manufacturer']))

# %%
print(len(lst_FDADMF))
# Out:
# 4695

# %%
lst_comweb = list(set(company_web.select('api_manufacturer').toPandas()['api_manufacturer']))

# %%
lst_common2 = [item for item in lst_FDADMF if item in lst_comweb ]

# %%
print(len(lst_common2))
# Out:
# 6

# %%
lst_comweb[:20]
# Out:
# ['Pharmagen Ltd.',
#  'Aarambh Life Science',
#  'Suzhou NeuPharma Co., Ltd.',
#  'Bio Sidus S.A.',
#  'Saraca Laboratories Ltd.',
#  'Concord Biotech Limited',
#  'Olainfarm AS',
#  'BYS Chem CO., Ltd',
#  'Miat S.p.A.',
#  'Suzhou ChiralPharm Technology Co., Ltd.',
#  'Nanjing King-friend Biochemical Pharmaceutical Co., Ltd',
#  'LGM Pharma',
#  'Formosa Laboratories, Inc.',
#  'AARTI Healthcare',
#  'Covex S.A.',
#  'Lupin Ltd',
#  'Recordati',
#  'Aceto Fine Chem GmbH',
#  'Kamada Ltd.',
#  'Sichuan Credit Chemwerth Pharmaceutical Co., Ltd.']

# %% [markdown]
# ### pc_company

# %%
company = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_company.csv")

# %%
company
# Out:
# +----------+--------------------+--------------------+--------------------+------------------+----------------+--------------------+--------------------+-------------------+------------+---------------+-------------------+
# |company_id|                name|             synonym|             address|              city|        US_state|             country|     company_website|          telephone|year_founded|employee_number|     moment_updated|
# +----------+--------------------+--------------------+--------------------+------------------+----------------+--------------------+--------------------+-------------------+------------+---------------+-------------------+
# |      3086|Crawford Healthca...|Crawford Pharmace...|King Edward Court...|          Cheshire|            null|      United Kingdom|https://www.crawf...|+44 (0) 1565 654920|        1996|           null|2020-07-20 17:01:47|
# |      1021|Kyowa Kirin Inter...|ProStrakan Group Plc|Galabank Business...|        Galashiels|            null|      United Kingdom|http://www.intern...|+44 (0) 1896 664000|        1995|           null|2020-06-30 09:45:31|
# |      7891|      Cantabria Labs|Industrial Farmac...|Calle Arequipa, 1...|            Madrid|            null|               Spain|https://www.canta...|   +34 677 53 07 86|        1949|            840|2020-04-20 17:23:17|
# |     19963|Cantabria Labs Di...|Difa Cooper S.p.A...|Via Milano, 160 2...|Caronno Pertusella|            null|               Italy|https://www.canta...|   (+39) 02.9659031|        1961|           null|2020-07-05 20:46:24|
# |      3063|      Wockhardt Ltd.|                null|Bandra Kurla Comp...|            Mumbai|            null|               India|http://www.wockha...|   +91 22 2653 4444|        1967|           6254|2020-06-17 23:31:30|
# |      5759|Hyundai Pharmaceu...|                null|204-4, Nonhyun-do...|             Seoul|            null|         South Korea|http://www.hyunda...|    +82-2-2600-3951|        1965|           null|2020-06-29 15:13:33|
# |         7|Abeona Therapeuti...|Access Pharmaceut...|1330 Avenue of th...|          New York|     NY-New York|United States of ...|http://abeonather...|       646-813-4712|        1974|             83|2020-06-27 13:22:20|
# |       392|AMAG Pharmaceutic...|Advanced Magnetic...|1100 Winter Stree...|           Waltham|MA-Massachusetts|United States of ...|https://www.amagp...|       617.498.3300|        1981|            467|2020-06-15 11:05:21|
# |      2282|RHEI Pharmaceutic...|RHEI Pharmaceutic...|Room 2004, 20/F C...|         Hong Kong|            null|           Hong Kong|                null|    +1 289 234 2586|        2004|           null|2020-06-13 11:22:56|
# |      2340|        Norgine B.V.|                null|Cross Towers, Ant...|         Amsterdam|            null|         Netherlands|http://www.norgin...|+31 (0)20 567 09 00|        1906|           null|2020-07-10 13:54:55|
# |     11781|         SpePharm AG|                null|c/o Dr. Adrian vo...|            Luzern|            null|         Netherlands|http://www.spepha...|+49 (0)172 726 7656|        2012|           null|2020-02-09 16:52:31|
# |       990|Hanmi Pharmaceuti...|       Hanmi Science|14, Wiryeseong-da...|             Seoul|            null|         South Korea|http://www.hanmip...|     +82-2-410-9114|        1973|           null|2020-07-22 16:58:22|
# |         9|         Acrux, Ltd.|                null|103-113 Stanley S...|         Melbourne|            null|           Australia|http://www.acrux....|    +61 3 8379 0100|        1998|           null|2020-07-21 15:53:38|
# |      1070|     Perrigo Co. plc|Blisfont Limited|...|The Sharp Buildin...|            Dublin|            null|             Ireland|http://www.perrig...|    +353 1 709 4000|        1887|          10600|2020-06-22 15:03:08|
# |      3597|Aspen Pharmacare ...|     Pharmacare Ltd.|Aspen Place 9 Ryd...|            Durban|            null|        South Africa|http://www.aspenp...|     +27 31 5808600|        1850|          10676|2020-07-21 14:38:58|
# |      3418|  Vifor Pharma, Ltd.|Vifor Pharma AG||...|Flughofstrasse 61...|        Glattbrugg|            null|         Switzerland|http://www.viforp...|       +41588518000|        2008|           2671|2020-06-06 12:09:26|
# |     15585|Alvogen Korea Co....|Kunwha Pharmaceut...|07326 13F. Two IF...|             Seoul|            null|         South Korea|http://en.alvogen...|    +82-2-2047-7700|        1958|            600|2020-05-26 15:38:35|
# |      5325|Lotus Pharmaceuti...|                null|17F, No. 277, Son...|       Taipei City|            null|              Taiwan|http://www.lotusp...|   +886 2 2700 5908|        1966|           null|2020-06-27 13:22:22|
# |      1876|Gedeon Richter Group|Gedeon Richter Pl...|Gyömrői út 19-21....|          Budapest|            null|             Hungary|http://www.richte...|      +36 1431 4000|        1901|          12667|2020-07-01 16:01:00|
# |      5612|Lee's Pharmaceuti...|                null|Unit 110-111, Bio...|         Hong Kong|            null|           Hong Kong|https://www.leesp...|    (852) 2314-1282|        1994|           1028|2020-06-06 12:09:26|
# +----------+--------------------+--------------------+--------------------+------------------+----------------+--------------------+--------------------+-------------------+------------+---------------+-------------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F
company.agg(*(100.0*(F.count(F.col(c))/company.count()).alias(c) for c in company.columns))
# Out:
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+
# |((count(company_id) / 3547) AS `company_id` * 100.0)|((count(name) / 3547) AS `name` * 100.0)|((count(synonym) / 3547) AS `synonym` * 100.0)|((count(address) / 3547) AS `address` * 100.0)|((count(city) / 3547) AS `city` * 100.0)|((count(US_state) / 3547) AS `US_state` * 100.0)|((count(country) / 3547) AS `country` * 100.0)|((count(company_website) / 3547) AS `company_website` * 100.0)|((count(telephone) / 3547) AS `telephone` * 100.0)|((count(year_founded) / 3547) AS `year_founded` * 100.0)|((count(employee_number) / 3547) AS `employee_number` * 100.0)|((count(moment_updated) / 3547) AS `moment_updated` * 100.0)|
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+
# |                                               100.0|                                   100.0|                             50.09867493656611|                                99.49252889766|                       99.57710741471666|                               30.10995207217367|                             99.88722864392444|                                             80.57513391598535|                                  92.1623907527488|                                       91.51395545531436|                                            14.942204680011278|                                                       100.0|
# +----------------------------------------------------+----------------------------------------+----------------------------------------------+----------------------------------------------+----------------------------------------+------------------------------------------------+----------------------------------------------+--------------------------------------------------------------+--------------------------------------------------+--------------------------------------------------------+--------------------------------------------------------------+------------------------------------------------------------+

# %%
pc_branch.agg(*(100.0*(F.count(F.col(c))/pc_branch.count()).alias(c) for c in pc_branch.columns))
# Out:
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+
# |((count(branch_id) / 1841) AS `branch_id` * 100.0)|((count(abbreviation) / 1841) AS `abbreviation` * 100.0)|((count(branch_name) / 1841) AS `branch_name` * 100.0)|((count(branch_synonym) / 1841) AS `branch_synonym` * 100.0)|((count(full_name) / 1841) AS `full_name` * 100.0)|((count(explanation) / 1841) AS `explanation` * 100.0)|((count(hyperlink) / 1841) AS `hyperlink` * 100.0)|((count(top_page) / 1841) AS `top_page` * 100.0)|((count(type) / 1841) AS `type` * 100.0)|((count(hide_in) / 1841) AS `hide_in` * 100.0)|((count(dds_type) / 1841) AS `dds_type` * 100.0)|
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+
# |                                             100.0|                                      11.298207495926126|                                     99.94568169473112|                                           36.93644758283541|                               0.27159152634437805|                                     4.942965779467681|                                21.944595328625745|                             0.16295491580662683|                       99.89136338946226|                            1.1950027159152634|                               98.91363389462249|
# +--------------------------------------------------+--------------------------------------------------------+------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------+--------------------------------------------------+------------------------------------------------+----------------------------------------+----------------------------------------------+------------------------------------------------+

# %%
#pc_branch.select('type').distinct().show()
pc_branch.select('branch_name').distinct().show(10, False)
# Out:
# +---------------------------+
# |branch_name                |
# +---------------------------+
# |Poration, Iontophoresis    |
# |Cancer, Testicular         |
# |Pulmonary Embolism         |
# |Ocular Absorption Enhancers|
# |Cancer, CCL                |
# |Photodynamic, Topical      |
# |Intrauterine Devices       |
# |Conventional Melt Tablets  |
# |Infections                 |
# |Hypoparathyroidism         |
# +---------------------------+
# only showing top 10 rows

# %% [markdown]
# ### pc_compound

# %%
compound = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_compound.csv")

# %%
#contain lot of partnership relation
compound
# Out:
# +-----------+--------------------+--------------------+-------------+-------------+-------------+-------------+----------+--------------------+-----------------------+--------------------+--------+----------------------+---------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------------+------------+---------------------+--------------------------------------+-----------------+--------------------------------------+-----------------+--------------------------------------+-----------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+------------------+-------------+------------------+-----------------+----------+--------------------+--------------------+--------+-------------------+-------------------+-------------+
# |compound_id|        product_name|     product_synonym|molecule_id_1|molecule_id_2|molecule_id_3|molecule_id_4|      type|generic_or_innovator|therapeutic_category_id|therapeutic_group_id|   phase|indication_explanation|route_branch_id|drug_delivery_branch_id_1|drug_delivery_branch_id_2|drug_delivery_branch_id_3|drug_delivery_branch_id_4|product_originator_company_id_1|product_originator_company_id_2|dds_technology_owner_company_id_1|dds_technology_owner_company_id_2|discovery_technology_owner_company_id|previous_partner_company_id_1|previous_partner_company_id_2|compound_company_id_1|compound_company_id_2|compound_company_id_3|compound_company_id_4|company_role_1|company_role_2|company_role_3|company_role_4| company_explanation|territory_id|manufacturing_details|API_manufacturing_partner_company_id_1|explanation_API_1|API_manufacturing_partner_company_id_2|explanation_API_2|API_manufacturing_partner_company_id_3|explanation_API_3|formulation_manufacturing_partner_company_id_1|explanation_formulation_manufacturing_1|formulation_manufacturing_partner_company_id_2|explanation_formulation_manufacturing_2|formulation_manufacturing_partner_company_id_3|explanation_formulation_manufacturing_3|parent_compound_id|approval_date|market_launch_date|registration_date|  activity|last_activity_change| last_changed_fields|group_id|     moment_updated|    moment_inserted|highest_phase|
# +-----------+--------------------+--------------------+-------------+-------------+-------------+-------------+----------+--------------------+-----------------------+--------------------+--------+----------------------+---------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------------+------------+---------------------+--------------------------------------+-----------------+--------------------------------------+-----------------+--------------------------------------+-----------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+------------------+-------------+------------------+-----------------+----------+--------------------+--------------------+--------+-------------------+-------------------+-------------+
# |          2|Darvocet A500 Tab...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                   1|Marketed|                  null|              9|                     1382|                     null|                     null|                     null|                              5|                           null|                             null|                             null|                                 null|                         null|                         null|                 1465|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2003-09-10|              null|             null|not active|          2012-02-06|Company,Marketing...|       2|2019-03-26 08:42:56|2006-03-28 15:18:45|     Marketed|
# |       5192| Balacet 325 Tablets|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                6898|Marketed|  Indicated for the...|              9|                     1382|                     null|                     null|                     null|                           1429|                           null|                             null|                             null|                                 null|                         null|                         null|                  999|                 1056|                 2507|                 null| product owner|  co-promotion|  co-promotion|          null|In April 2007, Co...|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2004-05-07|              null|             null|not active|          2017-04-19|Clinical Trial,Dr...|    5192|2017-10-04 15:05:27|2006-04-07 13:15:53|     Marketed|
# |       8978|Darvocet-N 50 and...|propoxyphene naps...|            2|          887|         null|         null|pharma/bio|     new combination|                   1454|               12790|Marketed|                  null|              9|                     1382|                     null|                     null|                     null|                              5|                           null|                             null|                             null|                                 null|                         null|                         null|                 1465|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1972-12-19|              null|             null|not active|          2010-11-19|Adverse Reactions...|    8978|2017-10-04 15:05:27|2006-03-23 17:32:36|     Marketed|
# |       8980|    Darvon-N Tablets|         Darvon N100|            2|         null|         null|         null|pharma/bio|     new formulation|                   1454|               12792|Marketed|  relief of mild to...|              9|                     1382|                     null|                     null|                     null|                              5|                           null|                             null|                             null|                                 null|                         null|                         null|                 1465|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1971-09-09|              null|       1971-07-19|not active|          2010-11-19|How Supplied,Indi...|    8980|2017-10-04 15:05:27|2006-03-23 17:32:36|     Marketed|
# |      30285|  Darvon-N Tablets 2|                null|            2|         null|         null|         null|pharma/bio|     new formulation|                   1454|               12792|Marketed|  Mild to moderate ...|              9|                     1382|                     null|                     null|                     null|                              5|                           null|                             null|                             null|                                 null|                         null|                         null|                 1465|                  626|                 null|                 null| product owner|          null|          null|          null|                null|          27|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              8980|   1973-12-31|              null|             null|not active|                null|How Supplied,Indi...|    8980|2017-10-04 15:05:27|2009-08-22 11:17:25|     Marketed|
# |     115108|    Darvocet Tablets|                null|            2|          887|         null|         null|pharma/bio|     new combination|                   1454|                null|Marketed|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                    5|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1972-10-18|              null|             null|not active|          2014-02-21|Company,Indicatio...|  115108|2017-10-04 15:05:27|2014-02-19 17:15:35|     Marketed|
# |     209273|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  680|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1985-06-12|              null|             null|not active|          2010-11-19|                null|  209273|2017-10-04 15:05:27|2017-03-27 13:12:59|     Approved|
# |     209274|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  326|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1985-06-12|              null|             null|not active|          2010-11-19|                null|  209274|2017-10-04 15:05:27|2017-03-27 13:13:00|     Approved|
# |     209276|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  381|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1985-06-12|              null|             null|not active|          2010-11-19|                null|  209276|2017-10-04 15:05:27|2017-03-27 13:13:00|     Approved|
# |     209277|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                 3434|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1985-08-02|              null|             null|not active|          2010-11-19|                null|  209277|2017-10-04 15:05:27|2017-03-27 13:13:00|     Approved|
# |     209278|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  341|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1986-12-18|              null|             null|not active|          2010-11-19|                null|  209278|2017-10-04 15:05:27|2017-03-27 13:13:01|     Approved|
# |     209284|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  341|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1987-01-02|              null|             null|not active|          2010-11-19|                null|  209284|2017-10-04 15:05:27|2017-03-27 13:13:02|     Approved|
# |     209285|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                13991|                  381|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1988-02-16|              null|             null|not active|          2010-11-19|                null|  209285|2019-05-15 10:46:40|2017-03-27 13:13:03|     Approved|
# |     209287|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  579|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2001-02-02|              null|             null|not active|          2010-11-19|                null|  209287|2017-10-04 15:05:27|2017-03-27 13:13:04|     Approved|
# |     209288|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                 1977|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2001-07-11|              null|             null|not active|          2010-11-19|                null|  209288|2017-10-04 15:05:27|2017-03-27 13:13:04|     Approved|
# |     209289|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  341|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2004-11-16|              null|             null|not active|          2010-11-19|                null|  209289|2017-10-04 15:05:27|2017-03-27 13:13:05|     Approved|
# |     209290|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                 1429|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2004-06-28|              null|             null|not active|          2010-11-19|                null|  209290|2017-10-04 15:05:27|2017-03-27 13:13:05|     Approved|
# |     209292|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                 3063|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2007-03-16|              null|             null|not active|          2010-11-19|                null|  209292|2017-10-04 15:05:27|2017-03-27 13:13:06|     Approved|
# |     209293|Darvocet-N 50 and...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                11549|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   2008-02-11|              null|             null|not active|          2010-11-19|                null|  209293|2017-10-04 15:05:27|2017-03-27 13:13:06|     Approved|
# |     211381|Darvocet, Generic...|                null|            2|          887|         null|         null|pharma/bio|             generic|                   1454|                null|Approved|                  null|              9|                     1382|                     null|                     null|                     null|                           null|                           null|                             null|                             null|                                 null|                         null|                         null|                  341|                 null|                 null|                 null| product owner|          null|          null|          null|                null|           6|                 null|                                  null|             null|                                  null|             null|                                  null|             null|                                          null|                                   null|                                          null|                                   null|                                          null|                                   null|              null|   1996-12-16|              null|             null|not active|          2014-02-21|                null|  211381|2017-10-04 15:05:27|2017-03-27 13:44:55|     Approved|
# +-----------+--------------------+--------------------+-------------+-------------+-------------+-------------+----------+--------------------+-----------------------+--------------------+--------+----------------------+---------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------------+-------------------------------+---------------------------------+---------------------------------+-------------------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+---------------------+--------------+--------------+--------------+--------------+--------------------+------------+---------------------+--------------------------------------+-----------------+--------------------------------------+-----------------+--------------------------------------+-----------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+----------------------------------------------+---------------------------------------+------------------+-------------+------------------+-----------------+----------+--------------------+--------------------+--------+-------------------+-------------------+-------------+
# only showing top 20 rows

# %%
print(list(compound.schema))
# Out:
# [StructField(compound_id,StringType,true), StructField(product_name,StringType,true), StructField(product_synonym,StringType,true), StructField(molecule_id_1,StringType,true), StructField(molecule_id_2,StringType,true), StructField(molecule_id_3,StringType,true), StructField(molecule_id_4,StringType,true), StructField(type,StringType,true), StructField(generic_or_innovator,StringType,true), StructField(therapeutic_category_id,StringType,true), StructField(therapeutic_group_id,StringType,true), StructField(phase,StringType,true), StructField(indication_explanation,StringType,true), StructField(route_branch_id,StringType,true), StructField(drug_delivery_branch_id_1,StringType,true), StructField(drug_delivery_branch_id_2,StringType,true), StructField(drug_delivery_branch_id_3,StringType,true), StructField(drug_delivery_branch_id_4,StringType,true), StructField(product_originator_company_id_1,StringType,true), StructField(product_originator_company_id_2,StringType,true), StructField(dds_technology_owner_company_id_1,StringType,true), StructField(dds_technology_owner_company_id_2,StringType,true), StructField(discovery_technology_owner_company_id,StringType,true), StructField(previous_partner_company_id_1,StringType,true), StructField(previous_partner_company_id_2,StringType,true), StructField(compound_company_id_1,StringType,true), StructField(compound_company_id_2,StringType,true), StructField(compound_company_id_3,StringType,true), StructField(compound_company_id_4,StringType,true), StructField(company_role_1,StringType,true), StructField(company_role_2,StringType,true), StructField(company_role_3,StringType,true), StructField(company_role_4,StringType,true), StructField(company_explanation,StringType,true), StructField(territory_id,StringType,true), StructField(manufacturing_details,StringType,true), StructField(API_manufacturing_partner_company_id_1,StringType,true), StructField(explanation_API_1,StringType,true), StructField(API_manufacturing_partner_company_id_2,StringType,true), StructField(explanation_API_2,StringType,true), StructField(API_manufacturing_partner_company_id_3,StringType,true), StructField(explanation_API_3,StringType,true), StructField(formulation_manufacturing_partner_company_id_1,StringType,true), StructField(explanation_formulation_manufacturing_1,StringType,true), StructField(formulation_manufacturing_partner_company_id_2,StringType,true), StructField(explanation_formulation_manufacturing_2,StringType,true), StructField(formulation_manufacturing_partner_company_id_3,StringType,true), StructField(explanation_formulation_manufacturing_3,StringType,true), StructField(parent_compound_id,StringType,true), StructField(approval_date,StringType,true), StructField(market_launch_date,StringType,true), StructField(registration_date,StringType,true), StructField(activity,StringType,true), StructField(last_activity_change,StringType,true), StructField(last_changed_fields,StringType,true), StructField(group_id,StringType,true), StructField(moment_updated,StringType,true), StructField(moment_inserted,StringType,true), StructField(highest_phase,StringType,true)]

# %%
compound_comb = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_compound_combined.csv")

# %%
compound_comb

# %% [markdown]
# ### Molecule

# %%
molecule = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_molecule.csv")

# %%
# has molecules in pipelines
molecule
# Out:
# +-----------+--------------------+--------------------+---------------+------------+
# |molecule_id|       molecule_name|             synonym|    unii_number|CAS_registry|
# +-----------+--------------------+--------------------+---------------+------------+
# |          2|propoxyphene naps...|(+)- Propoxyphene...|           null|  17140-78-2|
# |        887|         paracetamol|acetaminophen||ac...|UNII-362O9ITL9D|    103-90-2|
# |          3|morphine sulfate ...|Di(morphine) dihy...|UNII-X3P646A2J0|   6211-15-0|
# |        344|clindamycin phosp...|clindamycini phos...|UNII-EH6D7113I8|  24729-96-2|
# |       2888|            glycerin|glycerol||propane...|           null|     56-81-5|
# |       3715|         citric acid|4-03-00-01272 ||A...|UNII-XF417D3PSL|     77-92-9|
# |       3751|      benzyl alcohol|BnOH||(Hydroxymet...|           null|    100-51-6|
# |      24631| potassium hydroxide|Caswell No. 693||...|UNII-WZH3C48M4T|   1310-58-3|
# |          6|           amlexanox|AA673||AA-673||AA...|UNII-BRL1C2459K|  68302-57-8|
# |       1256|estradiol hemihyd...|beta-Estradiol se...|UNII-CXY7B3Q98Z|  35380-71-3|
# |          8|        testosterone|Testosterona||Tes...|UNII-3XMK78S47O|     58-22-0|
# |        866|lidocaine hydroch...|Lidocaine HCl hyd...|UNII-V13007Z41A|   6108-05-0|
# |       2343|          cetilistat|ATL-962||ATL 962|...|           null| 282526-98-1|
# |         28|prazosin hydrochl...|CP 12299-1||CP-12...|UNII-X0Z7454B90|  19237-84-4|
# |         30|methylphenidate h...|methylphenidate H...|UNII-4B3SC438HI|    298-59-9|
# |         34|         scopolamine|Hyoscine||Hyosol|...|UNII-DL48G20X8X|     51-34-3|
# |         35|doxorubicin hydro...|hydroxydaunorubic...|UNII-82F2G7BL4E|  25316-40-9|
# |         37|tetracycline hydr...|AI3-50120||ALA TE...|UNII-P6R62377KV|     64-75-5|
# |         39|          naltrexone|Naltrexona||Naltr...|UNII-5S6W795CQM|  16590-41-3|
# |        208|diltiazem hydroch...|CRD 401||CRD401||...|UNII-OLH94387TE|  33286-22-5|
# +-----------+--------------------+--------------------+---------------+------------+
# only showing top 20 rows

# %%
molecule.agg(*(100.0*(F.count(F.col(c))/molecule.count()).alias(c) for c in molecule.columns))
# Out:
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+
# |((count(molecule_id) / 3984) AS `molecule_id` * 100.0)|((count(molecule_name) / 3984) AS `molecule_name` * 100.0)|((count(synonym) / 3984) AS `synonym` * 100.0)|((count(unii_number) / 3984) AS `unii_number` * 100.0)|((count(CAS_registry) / 3984) AS `CAS_registry` * 100.0)|
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+
# |                                                 100.0|                                                     100.0|                             81.70180722891565|                                     53.26305220883534|                                       90.06024096385542|
# +------------------------------------------------------+----------------------------------------------------------+----------------------------------------------+------------------------------------------------------+--------------------------------------------------------+

# %%
territory = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_territory.csv")

# %%
# territory seems goes withs ales
territory

# %%
sales_comp = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/Sales_Compound.csv")

# %%
sales_comp

# %%
sales = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/Sales.csv")

# %%
sales

# %%
pc_form = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv("/home/zhengrongma/supply_chain_project/data/pharmacircle/pc_form.csv")

# %%
pc_form

# %%
path = "/home/zhengrongma/supply_chain_project/data/pharmacircle/"

file = "pc_form.csv"



test = pc_form = spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ";").csv(path + file)

# %%
test.count()

# %%
gsrs =  spark.read.option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ",").csv("/home/zhengrongma/supply_chain_project/data/unii_zip/gsrs.csv")

# %%
gsrs
# Out:
# +----------+--------------------+-------------------+----+
# |      unii|                name|             detail|type|
# +----------+--------------------+-------------------+----+
# |486026U8ME|HUMAN ADENOVIRUS ...|structurallyDiverse|self|
# |486026U8ME|HUMAN ADENOVIRUS ...|                 cn|name|
# |486026U8ME|MASTADENOVIRUS: H...|                sys|name|
# |486026U8ME| HUMAN ADENOVIRUS D9|                 cn|name|
# |486026U8ME|MASTADENOVIRUS: H...|                sys|name|
# |486026U8ME|               10527|      NCBI TAXONOMY|code|
# |A1HKS2R89E|PODOCARPUS NERIIF...|structurallyDiverse|self|
# |A1HKS2R89E|PODOCARPUS ENDLIC...|                sys|name|
# |A1HKS2R89E|NAGEIA LEPTOSTACH...|                 cn|name|
# |A1HKS2R89E|NAGEIA DISCOLOR W...|                 cn|name|
# |A1HKS2R89E|MARGBENSONIA NERI...|                sys|name|
# |A1HKS2R89E|PODOCARPUS LEPTOS...|                 cn|name|
# |A1HKS2R89E|PODOCARPUS NERIIF...|                sys|name|
# |A1HKS2R89E|NAGEIA NEGLECTA W...|                 cn|name|
# |A1HKS2R89E|PODOCARPUS DECIPI...|                 cn|name|
# |A1HKS2R89E|NAGEIA ENDLICHERI...|                sys|name|
# |A1HKS2R89E|    BROWN PINE WHOLE|                 cn|name|
# |A1HKS2R89E|PODOCARPUS DISCOL...|                 cn|name|
# |A1HKS2R89E|NAGEIA NERIIFOLIA...|                sys|name|
# |A1HKS2R89E| MOUNTAIN TEAK WHOLE|                 cn|name|
# +----------+--------------------+-------------------+----+
# only showing top 20 rows

# %%
name_lookup = ( gsrs
                .filter(gsrs.type == 'self')
                .join( gsrs.withColumnRenamed('name','synonym'),'unii')
               .drop('detail', 'type')
              )

# %%
name_lookup = name_lookup.withColumn('synonym_formated', F.regexp_replace(F.col('synonym'), r'\[(.*?)\]', ''))

# %%
name_lookup = name_lookup.withColumn('synonym_formated', F.trim(F.lower(F.col('synonym_formated'))))

# %%
matched = api_manufacturer.select(F.lower(F.col('api')).alias('api_lower')).join(name_lookup,
                                                           F.col('api_lower') == F.lower(F.col('synonym_formated')) ).select('api_lower','unii','synonym_formated').dropDuplicates()

# %%
#first pass match 9409 
# convert to lower case and strip [] 9414
matched.count()
# Out:
# 9349

# %%
matched
# Out:
# +--------------------+----------+--------------------+
# |           api_lower|      unii|    synonym_formated|
# +--------------------+----------+--------------------+
# |    atropine sulfate|03J5ZE7KA5|    atropine sulfate|
# |   atropine sulphate|03J5ZE7KA5|   atropine sulphate|
# |atropine sulfate ...|03J5ZE7KA5|atropine sulfate ...|
# |       thiopropazate|0JFY081Q2X|       thiopropazate|
# |         laurocapram|1F3X9DRV9X|         laurocapram|
# |               azone|1F3X9DRV9X|               azone|
# |7-keto-dehydroepi...|2334LJD2E9|7-keto-dehydroepi...|
# |        metopimazine|238S75V9AV|        metopimazine|
# |          etofibrate|23TF67G79M|          etofibrate|
# |sodium carbonate ...|2A1Q1Q3557|sodium carbonate ...|
# |mecysteine hydroc...|33RG619160|mecysteine hydroc...|
# |   aluminum chloride|3CYT62D3GA|   aluminum chloride|
# |           macrogols|3WJQ0SDW1A|           macrogols|
# |            macrogol|3WJQ0SDW1A|            macrogol|
# | polyethylene glycol|3WJQ0SDW1A| polyethylene glycol|
# |polyethylene glycols|3WJQ0SDW1A|polyethylene glycols|
# |benzomethamine ch...|47S7HSY6PC|benzomethamine ch...|
# |     lipegfilgrastim|4AWF0N6QV3|     lipegfilgrastim|
# |        dl-glutamine|5L555N1902|        dl-glutamine|
# |          volasertib|6EM57086EA|          volasertib|
# +--------------------+----------+--------------------+
# only showing top 20 rows

# %%
gsrs.show(40, False)
# Out:
# +----------+-------------------------------------------------------+-------------------+----+
# |unii      |name                                                   |detail             |type|
# +----------+-------------------------------------------------------+-------------------+----+
# |486026U8ME|HUMAN ADENOVIRUS D SEROTYPE 9                          |structurallyDiverse|self|
# |486026U8ME|HUMAN ADENOVIRUS D SEROTYPE 9                          |cn                 |name|
# |486026U8ME|MASTADENOVIRUS: HUMAN MASTADENOVIRUS D SEROTYPE 9 WHOLE|sys                |name|
# |486026U8ME|HUMAN ADENOVIRUS D9                                    |cn                 |name|
# |486026U8ME|MASTADENOVIRUS: HUMAN MASTADENOVIRUS D SEROTYPE 9      |sys                |name|
# |486026U8ME|10527                                                  |NCBI TAXONOMY      |code|
# |A1HKS2R89E|PODOCARPUS NERIIFOLIUS WHOLE                           |structurallyDiverse|self|
# |A1HKS2R89E|PODOCARPUS ENDLICHERIANUS WHOLE                        |sys                |name|
# |A1HKS2R89E|NAGEIA LEPTOSTACHYA WHOLE                              |cn                 |name|
# |A1HKS2R89E|NAGEIA DISCOLOR WHOLE                                  |cn                 |name|
# |A1HKS2R89E|MARGBENSONIA NERIIFOLIA WHOLE                          |sys                |name|
# |A1HKS2R89E|PODOCARPUS LEPTOSTACHYUS WHOLE                         |cn                 |name|
# |A1HKS2R89E|PODOCARPUS NERIIFOLIUS D.DON                           |sys                |name|
# |A1HKS2R89E|NAGEIA NEGLECTA WHOLE                                  |cn                 |name|
# |A1HKS2R89E|PODOCARPUS DECIPIENS WHOLE                             |cn                 |name|
# |A1HKS2R89E|NAGEIA ENDLICHERIANA WHOLE                             |sys                |name|
# |A1HKS2R89E|BROWN PINE WHOLE                                       |cn                 |name|
# |A1HKS2R89E|PODOCARPUS DISCOLOR WHOLE                              |cn                 |name|
# |A1HKS2R89E|NAGEIA NERIIFOLIA WHOLE                                |sys                |name|
# |A1HKS2R89E|MOUNTAIN TEAK WHOLE                                    |cn                 |name|
# |A1HKS2R89E|PODOCARPUS NEGLECTUS WHOLE                             |cn                 |name|
# |A1HKS2R89E|PODOCARPUS JUNGHUHNIANUS WHOLE                         |cn                 |name|
# |A1HKS2R89E|PODOCARPUS NERIIFOLIUS WHOLE                           |cn                 |name|
# |A1HKS2R89E|PODOCARPUS NERIIFOLIUS                                 |WIKIPEDIA          |code|
# |A1HKS2R89E|822557                                                 |ITIS               |code|
# |A1HKS2R89E|29124                                                  |GRIN               |code|
# |A1HKS2R89E|61307                                                  |NCBI TAXONOMY      |code|
# |A1HKS2R89E|PONE21                                                 |USDA PLANTS        |code|
# |A1HKS2R89E|WCS-380872                                             |MPNS               |code|
# |3L01IJ2B47|PALMITAMIDOPROPYL DIMETHYLAMINE                        |chemical           |self|
# |3L01IJ2B47|N-(3-(DIMETHYLAMINO)PROPYL)HEXADECANAMIDE              |sys                |name|
# |3L01IJ2B47|HEXADECANAMIDE, N-(3-(DIMETHYLAMINO)PROPYL)-           |sys                |name|
# |3L01IJ2B47|N',N'-DIMETHYL-N-HEXADECANOYL-1,3-DIAMINOPROPANE       |sys                |name|
# |3L01IJ2B47|LEXAMINE P-13                                          |bn                 |name|
# |3L01IJ2B47|TEGAMINE P 13                                          |bn                 |name|
# |3L01IJ2B47|PALMITAMIDOPROPYL DIMETHYLAMINE                        |of                 |name|
# |3L01IJ2B47|PALMITAMIDOPROPYL DIMETHYLAMINE [INCI]                 |cn                 |name|
# |3L01IJ2B47|N-(3-DIMETHYLAMINOPROPYL)PALMITAMIDE                   |sys                |name|
# |3L01IJ2B47|(3-HEXADECANOYLAMINOPROPYL)DIMETHYLAMINE               |sys                |name|
# |3L01IJ2B47|SCHERCODINE P AMIDO-AMINE                              |bn                 |name|
# +----------+-------------------------------------------------------+-------------------+----+
# only showing top 40 rows

# %%
import re
str = "PALMITAMIDOPROPYL DIMETHYLAMINE [INCI]"
print(re.sub(r'\[(.*?)\]', '', str).strip())
# Out:
# PALMITAMIDOPROPYL DIMETHYLAMINE

# %%
name_lookup.withColumn('synonym_formated', F.regexp_replace(F.col('synonym'), r'\[(.*?)\]', ''))
# Out:
# +----------+----------------+--------------------+--------------------+
# |      unii|            name|             synonym|    synonym_formated|
# +----------+----------------+--------------------+--------------------+
# |01343Q8EL8|     ANISODAMINE|         ANISODAMINE|         ANISODAMINE|
# |01343Q8EL8|     ANISODAMINE|         ANISODAMINE|         ANISODAMINE|
# |01343Q8EL8|     ANISODAMINE|(-)-6.BETA.-HYDRO...|(-)-6.BETA.-HYDRO...|
# |01343Q8EL8|     ANISODAMINE|HYOSCYAMINE, 6-HY...|HYOSCYAMINE, 6-HY...|
# |01343Q8EL8|     ANISODAMINE|BENZENEACETIC ACI...|BENZENEACETIC ACI...|
# |01343Q8EL8|     ANISODAMINE|ANISODAMINE [WHO-DD]|        ANISODAMINE |
# |01343Q8EL8|     ANISODAMINE| ANISODAMINE [MART.]|        ANISODAMINE |
# |01343Q8EL8|     ANISODAMINE|6.BETA.-HYDROXYHY...|6.BETA.-HYDROXYHY...|
# |01343Q8EL8|     ANISODAMINE|            SUB25941|            SUB25941|
# |01343Q8EL8|     ANISODAMINE|         ANISODAMINE|         ANISODAMINE|
# |01343Q8EL8|     ANISODAMINE|          55869-99-3|          55869-99-3|
# |01343Q8EL8|     ANISODAMINE|             C003922|             C003922|
# |01343Q8EL8|     ANISODAMINE|             6918612|             6918612|
# |01343Q8EL8|     ANISODAMINE|           C17H23NO4|           C17H23NO4|
# |01343Q8EL8|     ANISODAMINE|            305.3688|            305.3688|
# |01343Q8EL8|     ANISODAMINE|CN1[C@@H]2C[C@H](...|CN12C(O)1C(C2)OC(...|
# |01343Q8EL8|     ANISODAMINE|          13NCM8S773|          13NCM8S773|
# |029U06V15C|E-3030 FREE ACID|    E-3030 FREE ACID|    E-3030 FREE ACID|
# |029U06V15C|E-3030 FREE ACID|(2S)-3-(3-((2S)-3...|(2S)-3-(3-((2S)-3...|
# |029U06V15C|E-3030 FREE ACID|    E-3030 FREE ACID|    E-3030 FREE ACID|
# +----------+----------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Join between molecule and api

# %%
molecule_api = api_manufacturer.select(F.lower(F.col('api')).alias('api_lower')).join(molecule,
                                                                                       F.col('api_lower') == F.col('molecule_name')
                                                                                     ).dropDuplicates()

# %%
molecule_api.count()
# Out:
# 2718
